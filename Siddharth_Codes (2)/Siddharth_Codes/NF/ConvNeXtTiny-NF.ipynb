# %%
import numpy as np
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
from keras.models import Model
from keras.layers import Dense, GlobalAveragePooling2D
from keras.applications import DenseNet121
from sklearn.model_selection import train_test_split

# %%
x = np.load('/content/drive/MyDrive/NF/resized_images.npy')
y = np.load('/content/drive/MyDrive/NF/labels.npy')

# Perform train-test split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=7)

# Create DenseNet base
input_shape = x_train.shape[1:]  # Assuming x_train is a numpy array of images
input_shape
# Out:
# (128, 128, 3)

# %%
print(x_train.shape)
print(x_test.shape)
# Out:
# (2200, 128, 128, 3)
# (550, 128, 128, 3)

# %%
from tensorflow.keras.applications import ConvNeXtTiny
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.models import Model

def create_ConvNeXtTiny_base(input_shape):
    # Load ConvNeXtTiny model without the top layer
    base_model = ConvNeXtTiny(include_top=False, input_shape=input_shape)

    # Perform global average pooling
    x = base_model.output
    x = GlobalAveragePooling2D()(x)

    # Add a dense layer with 125 sigmoid activated neurons
    x = Dense(125, activation='sigmoid')(x)

    model = Model(inputs=base_model.input, outputs=x)
    return model

def create_classification_model(base_model, num_classes):
    # Freeze the base model layers
    for layer in base_model.layers:
        layer.trainable = True

    # Add a dense layer with softmax activation for classification
    x = Dense(num_classes, activation='softmax')(base_model.output)

    # Create the classification model
    model = Model(inputs=base_model.input, outputs=x)

    return model

base_model = create_ConvNeXtTiny_base(input_shape)

num_classes = 5  # Change this to the number of classes in your classification task
classification_model = create_classification_model(base_model, num_classes)

classification_model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/convnext/convnext_tiny_notop.h5
# 111650432/111650432 [==============================] - 1s 0us/step
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 128, 128, 3)]        0         []
#
#  convnext_tiny_prestem_norm  (None, 128, 128, 3)          0         ['input_1[0][0]']
#  alization (Normalization)
#
#  convnext_tiny_stem (Sequen  (None, 32, 32, 96)           4896      ['convnext_tiny_prestem_normal
#  tial)                                                              ization[0][0]']
#
#  convnext_tiny_stage_0_bloc  (None, 32, 32, 96)           4800      ['convnext_tiny_stem[0][0]']
#  k_0_depthwise_conv (Conv2D
#  )
#
#  convnext_tiny_stage_0_bloc  (None, 32, 32, 96)           192       ['convnext_tiny_stage_0_block_
#  k_0_layernorm (LayerNormal                                         0_depthwise_conv[0][0]']
#  ization)
#
#  convnext_tiny_stage_0_bloc  (None, 32, 32, 384)          37248     ['convnext_tiny_stage_0_block_
#  k_0_pointwise_conv_1 (Dens                                         0_layernorm[0][0]']
#  e)
#
#  convnext_tiny_stage_0_bloc  (None, 32, 32, 384)          0         ['convnext_tiny_stage_0_block_
#  k_0_gelu (Activation)                                              0_pointwise_conv_1[0][0]']
#
#  convnext_tiny_stage_0_bloc  (None, 32, 32, 96)           36960     ['convnext_tiny_stage_0_block_
#  k_0_pointwise_conv_2 (Dens                                         0_gelu[0][0]']
#  e)
#
#  convnext_tiny_stage_0_bloc  (None, 32, 32, 96)           96        ['convnext_tiny_stage_0_block_
#  k_0_layer_scale (LayerScal                                         0_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_tiny_stage_0_bloc  (None, 32, 32, 96)           0         ['convnext_tiny_stage_0_block_
#  k_0_identity (Activation)                                          0_layer_scale[0][0]']
#
#  tf.__operators__.add (TFOp  (None, 32, 32, 96)           0         ['convnext_tiny_stem[0][0]',
#  Lambda)                                                             'convnext_tiny_stage_0_block_
#                                                                     0_identity[0][0]']
#
#  convnext_tiny_stage_0_bloc  (None, 32, 32, 96)           4800      ['tf.__operators__.add[0][0]']
#  k_1_depthwise_conv (Conv2D
#  )
#
#  convnext_tiny_stage_0_bloc  (None, 32, 32, 96)           192       ['convnext_tiny_stage_0_block_
#  k_1_layernorm (LayerNormal                                         1_depthwise_conv[0][0]']
#  ization)
#
#  convnext_tiny_stage_0_bloc  (None, 32, 32, 384)          37248     ['convnext_tiny_stage_0_block_
#  k_1_pointwise_conv_1 (Dens                                         1_layernorm[0][0]']
#  e)
#
#  convnext_tiny_stage_0_bloc  (None, 32, 32, 384)          0         ['convnext_tiny_stage_0_block_
#  k_1_gelu (Activation)                                              1_pointwise_conv_1[0][0]']
#
#  convnext_tiny_stage_0_bloc  (None, 32, 32, 96)           36960     ['convnext_tiny_stage_0_block_
#  k_1_pointwise_conv_2 (Dens                                         1_gelu[0][0]']
#  e)
#
#  convnext_tiny_stage_0_bloc  (None, 32, 32, 96)           96        ['convnext_tiny_stage_0_block_
#  k_1_layer_scale (LayerScal                                         1_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_tiny_stage_0_bloc  (None, 32, 32, 96)           0         ['convnext_tiny_stage_0_block_
#  k_1_identity (Activation)                                          1_layer_scale[0][0]']
#
#  tf.__operators__.add_1 (TF  (None, 32, 32, 96)           0         ['tf.__operators__.add[0][0]',
#  OpLambda)                                                           'convnext_tiny_stage_0_block_
#                                                                     1_identity[0][0]']
#
#  convnext_tiny_stage_0_bloc  (None, 32, 32, 96)           4800      ['tf.__operators__.add_1[0][0]
#  k_2_depthwise_conv (Conv2D                                         ']
#  )
#
#  convnext_tiny_stage_0_bloc  (None, 32, 32, 96)           192       ['convnext_tiny_stage_0_block_
#  k_2_layernorm (LayerNormal                                         2_depthwise_conv[0][0]']
#  ization)
#
#  convnext_tiny_stage_0_bloc  (None, 32, 32, 384)          37248     ['convnext_tiny_stage_0_block_
#  k_2_pointwise_conv_1 (Dens                                         2_layernorm[0][0]']
#  e)
#
#  convnext_tiny_stage_0_bloc  (None, 32, 32, 384)          0         ['convnext_tiny_stage_0_block_
#  k_2_gelu (Activation)                                              2_pointwise_conv_1[0][0]']
#
#  convnext_tiny_stage_0_bloc  (None, 32, 32, 96)           36960     ['convnext_tiny_stage_0_block_
#  k_2_pointwise_conv_2 (Dens                                         2_gelu[0][0]']
#  e)
#
#  convnext_tiny_stage_0_bloc  (None, 32, 32, 96)           96        ['convnext_tiny_stage_0_block_
#  k_2_layer_scale (LayerScal                                         2_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_tiny_stage_0_bloc  (None, 32, 32, 96)           0         ['convnext_tiny_stage_0_block_
#  k_2_identity (Activation)                                          2_layer_scale[0][0]']
#
#  tf.__operators__.add_2 (TF  (None, 32, 32, 96)           0         ['tf.__operators__.add_1[0][0]
#  OpLambda)                                                          ',
#                                                                      'convnext_tiny_stage_0_block_
#                                                                     2_identity[0][0]']
#
#  convnext_tiny_downsampling  (None, 16, 16, 192)          74112     ['tf.__operators__.add_2[0][0]
#  _block_0 (Sequential)                                              ']
#
#  convnext_tiny_stage_1_bloc  (None, 16, 16, 192)          9600      ['convnext_tiny_downsampling_b
#  k_0_depthwise_conv (Conv2D                                         lock_0[0][0]']
#  )
#
#  convnext_tiny_stage_1_bloc  (None, 16, 16, 192)          384       ['convnext_tiny_stage_1_block_
#  k_0_layernorm (LayerNormal                                         0_depthwise_conv[0][0]']
#  ization)
#
#  convnext_tiny_stage_1_bloc  (None, 16, 16, 768)          148224    ['convnext_tiny_stage_1_block_
#  k_0_pointwise_conv_1 (Dens                                         0_layernorm[0][0]']
#  e)
#
#  convnext_tiny_stage_1_bloc  (None, 16, 16, 768)          0         ['convnext_tiny_stage_1_block_
#  k_0_gelu (Activation)                                              0_pointwise_conv_1[0][0]']
#
#  convnext_tiny_stage_1_bloc  (None, 16, 16, 192)          147648    ['convnext_tiny_stage_1_block_
#  k_0_pointwise_conv_2 (Dens                                         0_gelu[0][0]']
#  e)
#
#  convnext_tiny_stage_1_bloc  (None, 16, 16, 192)          192       ['convnext_tiny_stage_1_block_
#  k_0_layer_scale (LayerScal                                         0_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_tiny_stage_1_bloc  (None, 16, 16, 192)          0         ['convnext_tiny_stage_1_block_
#  k_0_identity (Activation)                                          0_layer_scale[0][0]']
#
#  tf.__operators__.add_3 (TF  (None, 16, 16, 192)          0         ['convnext_tiny_downsampling_b
#  OpLambda)                                                          lock_0[0][0]',
#                                                                      'convnext_tiny_stage_1_block_
#                                                                     0_identity[0][0]']
#
#  convnext_tiny_stage_1_bloc  (None, 16, 16, 192)          9600      ['tf.__operators__.add_3[0][0]
#  k_1_depthwise_conv (Conv2D                                         ']
#  )
#
#  convnext_tiny_stage_1_bloc  (None, 16, 16, 192)          384       ['convnext_tiny_stage_1_block_
#  k_1_layernorm (LayerNormal                                         1_depthwise_conv[0][0]']
#  ization)
#
#  convnext_tiny_stage_1_bloc  (None, 16, 16, 768)          148224    ['convnext_tiny_stage_1_block_
#  k_1_pointwise_conv_1 (Dens                                         1_layernorm[0][0]']
#  e)
#
#  convnext_tiny_stage_1_bloc  (None, 16, 16, 768)          0         ['convnext_tiny_stage_1_block_
#  k_1_gelu (Activation)                                              1_pointwise_conv_1[0][0]']
#
#  convnext_tiny_stage_1_bloc  (None, 16, 16, 192)          147648    ['convnext_tiny_stage_1_block_
#  k_1_pointwise_conv_2 (Dens                                         1_gelu[0][0]']
#  e)
#
#  convnext_tiny_stage_1_bloc  (None, 16, 16, 192)          192       ['convnext_tiny_stage_1_block_
#  k_1_layer_scale (LayerScal                                         1_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_tiny_stage_1_bloc  (None, 16, 16, 192)          0         ['convnext_tiny_stage_1_block_
#  k_1_identity (Activation)                                          1_layer_scale[0][0]']
#
#  tf.__operators__.add_4 (TF  (None, 16, 16, 192)          0         ['tf.__operators__.add_3[0][0]
#  OpLambda)                                                          ',
#                                                                      'convnext_tiny_stage_1_block_
#                                                                     1_identity[0][0]']
#
#  convnext_tiny_stage_1_bloc  (None, 16, 16, 192)          9600      ['tf.__operators__.add_4[0][0]
#  k_2_depthwise_conv (Conv2D                                         ']
#  )
#
#  convnext_tiny_stage_1_bloc  (None, 16, 16, 192)          384       ['convnext_tiny_stage_1_block_
#  k_2_layernorm (LayerNormal                                         2_depthwise_conv[0][0]']
#  ization)
#
#  convnext_tiny_stage_1_bloc  (None, 16, 16, 768)          148224    ['convnext_tiny_stage_1_block_
#  k_2_pointwise_conv_1 (Dens                                         2_layernorm[0][0]']
#  e)
#
#  convnext_tiny_stage_1_bloc  (None, 16, 16, 768)          0         ['convnext_tiny_stage_1_block_
#  k_2_gelu (Activation)                                              2_pointwise_conv_1[0][0]']
#
#  convnext_tiny_stage_1_bloc  (None, 16, 16, 192)          147648    ['convnext_tiny_stage_1_block_
#  k_2_pointwise_conv_2 (Dens                                         2_gelu[0][0]']
#  e)
#
#  convnext_tiny_stage_1_bloc  (None, 16, 16, 192)          192       ['convnext_tiny_stage_1_block_
#  k_2_layer_scale (LayerScal                                         2_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_tiny_stage_1_bloc  (None, 16, 16, 192)          0         ['convnext_tiny_stage_1_block_
#  k_2_identity (Activation)                                          2_layer_scale[0][0]']
#
#  tf.__operators__.add_5 (TF  (None, 16, 16, 192)          0         ['tf.__operators__.add_4[0][0]
#  OpLambda)                                                          ',
#                                                                      'convnext_tiny_stage_1_block_
#                                                                     2_identity[0][0]']
#
#  convnext_tiny_downsampling  (None, 8, 8, 384)            295680    ['tf.__operators__.add_5[0][0]
#  _block_1 (Sequential)                                              ']
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 384)            19200     ['convnext_tiny_downsampling_b
#  k_0_depthwise_conv (Conv2D                                         lock_1[0][0]']
#  )
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 384)            768       ['convnext_tiny_stage_2_block_
#  k_0_layernorm (LayerNormal                                         0_depthwise_conv[0][0]']
#  ization)
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 1536)           591360    ['convnext_tiny_stage_2_block_
#  k_0_pointwise_conv_1 (Dens                                         0_layernorm[0][0]']
#  e)
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 1536)           0         ['convnext_tiny_stage_2_block_
#  k_0_gelu (Activation)                                              0_pointwise_conv_1[0][0]']
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 384)            590208    ['convnext_tiny_stage_2_block_
#  k_0_pointwise_conv_2 (Dens                                         0_gelu[0][0]']
#  e)
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 384)            384       ['convnext_tiny_stage_2_block_
#  k_0_layer_scale (LayerScal                                         0_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 384)            0         ['convnext_tiny_stage_2_block_
#  k_0_identity (Activation)                                          0_layer_scale[0][0]']
#
#  tf.__operators__.add_6 (TF  (None, 8, 8, 384)            0         ['convnext_tiny_downsampling_b
#  OpLambda)                                                          lock_1[0][0]',
#                                                                      'convnext_tiny_stage_2_block_
#                                                                     0_identity[0][0]']
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 384)            19200     ['tf.__operators__.add_6[0][0]
#  k_1_depthwise_conv (Conv2D                                         ']
#  )
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 384)            768       ['convnext_tiny_stage_2_block_
#  k_1_layernorm (LayerNormal                                         1_depthwise_conv[0][0]']
#  ization)
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 1536)           591360    ['convnext_tiny_stage_2_block_
#  k_1_pointwise_conv_1 (Dens                                         1_layernorm[0][0]']
#  e)
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 1536)           0         ['convnext_tiny_stage_2_block_
#  k_1_gelu (Activation)                                              1_pointwise_conv_1[0][0]']
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 384)            590208    ['convnext_tiny_stage_2_block_
#  k_1_pointwise_conv_2 (Dens                                         1_gelu[0][0]']
#  e)
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 384)            384       ['convnext_tiny_stage_2_block_
#  k_1_layer_scale (LayerScal                                         1_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 384)            0         ['convnext_tiny_stage_2_block_
#  k_1_identity (Activation)                                          1_layer_scale[0][0]']
#
#  tf.__operators__.add_7 (TF  (None, 8, 8, 384)            0         ['tf.__operators__.add_6[0][0]
#  OpLambda)                                                          ',
#                                                                      'convnext_tiny_stage_2_block_
#                                                                     1_identity[0][0]']
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 384)            19200     ['tf.__operators__.add_7[0][0]
#  k_2_depthwise_conv (Conv2D                                         ']
#  )
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 384)            768       ['convnext_tiny_stage_2_block_
#  k_2_layernorm (LayerNormal                                         2_depthwise_conv[0][0]']
#  ization)
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 1536)           591360    ['convnext_tiny_stage_2_block_
#  k_2_pointwise_conv_1 (Dens                                         2_layernorm[0][0]']
#  e)
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 1536)           0         ['convnext_tiny_stage_2_block_
#  k_2_gelu (Activation)                                              2_pointwise_conv_1[0][0]']
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 384)            590208    ['convnext_tiny_stage_2_block_
#  k_2_pointwise_conv_2 (Dens                                         2_gelu[0][0]']
#  e)
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 384)            384       ['convnext_tiny_stage_2_block_
#  k_2_layer_scale (LayerScal                                         2_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 384)            0         ['convnext_tiny_stage_2_block_
#  k_2_identity (Activation)                                          2_layer_scale[0][0]']
#
#  tf.__operators__.add_8 (TF  (None, 8, 8, 384)            0         ['tf.__operators__.add_7[0][0]
#  OpLambda)                                                          ',
#                                                                      'convnext_tiny_stage_2_block_
#                                                                     2_identity[0][0]']
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 384)            19200     ['tf.__operators__.add_8[0][0]
#  k_3_depthwise_conv (Conv2D                                         ']
#  )
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 384)            768       ['convnext_tiny_stage_2_block_
#  k_3_layernorm (LayerNormal                                         3_depthwise_conv[0][0]']
#  ization)
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 1536)           591360    ['convnext_tiny_stage_2_block_
#  k_3_pointwise_conv_1 (Dens                                         3_layernorm[0][0]']
#  e)
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 1536)           0         ['convnext_tiny_stage_2_block_
#  k_3_gelu (Activation)                                              3_pointwise_conv_1[0][0]']
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 384)            590208    ['convnext_tiny_stage_2_block_
#  k_3_pointwise_conv_2 (Dens                                         3_gelu[0][0]']
#  e)
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 384)            384       ['convnext_tiny_stage_2_block_
#  k_3_layer_scale (LayerScal                                         3_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 384)            0         ['convnext_tiny_stage_2_block_
#  k_3_identity (Activation)                                          3_layer_scale[0][0]']
#
#  tf.__operators__.add_9 (TF  (None, 8, 8, 384)            0         ['tf.__operators__.add_8[0][0]
#  OpLambda)                                                          ',
#                                                                      'convnext_tiny_stage_2_block_
#                                                                     3_identity[0][0]']
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 384)            19200     ['tf.__operators__.add_9[0][0]
#  k_4_depthwise_conv (Conv2D                                         ']
#  )
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 384)            768       ['convnext_tiny_stage_2_block_
#  k_4_layernorm (LayerNormal                                         4_depthwise_conv[0][0]']
#  ization)
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 1536)           591360    ['convnext_tiny_stage_2_block_
#  k_4_pointwise_conv_1 (Dens                                         4_layernorm[0][0]']
#  e)
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 1536)           0         ['convnext_tiny_stage_2_block_
#  k_4_gelu (Activation)                                              4_pointwise_conv_1[0][0]']
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 384)            590208    ['convnext_tiny_stage_2_block_
#  k_4_pointwise_conv_2 (Dens                                         4_gelu[0][0]']
#  e)
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 384)            384       ['convnext_tiny_stage_2_block_
#  k_4_layer_scale (LayerScal                                         4_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 384)            0         ['convnext_tiny_stage_2_block_
#  k_4_identity (Activation)                                          4_layer_scale[0][0]']
#
#  tf.__operators__.add_10 (T  (None, 8, 8, 384)            0         ['tf.__operators__.add_9[0][0]
#  FOpLambda)                                                         ',
#                                                                      'convnext_tiny_stage_2_block_
#                                                                     4_identity[0][0]']
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 384)            19200     ['tf.__operators__.add_10[0][0
#  k_5_depthwise_conv (Conv2D                                         ]']
#  )
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 384)            768       ['convnext_tiny_stage_2_block_
#  k_5_layernorm (LayerNormal                                         5_depthwise_conv[0][0]']
#  ization)
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 1536)           591360    ['convnext_tiny_stage_2_block_
#  k_5_pointwise_conv_1 (Dens                                         5_layernorm[0][0]']
#  e)
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 1536)           0         ['convnext_tiny_stage_2_block_
#  k_5_gelu (Activation)                                              5_pointwise_conv_1[0][0]']
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 384)            590208    ['convnext_tiny_stage_2_block_
#  k_5_pointwise_conv_2 (Dens                                         5_gelu[0][0]']
#  e)
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 384)            384       ['convnext_tiny_stage_2_block_
#  k_5_layer_scale (LayerScal                                         5_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 384)            0         ['convnext_tiny_stage_2_block_
#  k_5_identity (Activation)                                          5_layer_scale[0][0]']
#
#  tf.__operators__.add_11 (T  (None, 8, 8, 384)            0         ['tf.__operators__.add_10[0][0
#  FOpLambda)                                                         ]',
#                                                                      'convnext_tiny_stage_2_block_
#                                                                     5_identity[0][0]']
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 384)            19200     ['tf.__operators__.add_11[0][0
#  k_6_depthwise_conv (Conv2D                                         ]']
#  )
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 384)            768       ['convnext_tiny_stage_2_block_
#  k_6_layernorm (LayerNormal                                         6_depthwise_conv[0][0]']
#  ization)
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 1536)           591360    ['convnext_tiny_stage_2_block_
#  k_6_pointwise_conv_1 (Dens                                         6_layernorm[0][0]']
#  e)
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 1536)           0         ['convnext_tiny_stage_2_block_
#  k_6_gelu (Activation)                                              6_pointwise_conv_1[0][0]']
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 384)            590208    ['convnext_tiny_stage_2_block_
#  k_6_pointwise_conv_2 (Dens                                         6_gelu[0][0]']
#  e)
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 384)            384       ['convnext_tiny_stage_2_block_
#  k_6_layer_scale (LayerScal                                         6_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 384)            0         ['convnext_tiny_stage_2_block_
#  k_6_identity (Activation)                                          6_layer_scale[0][0]']
#
#  tf.__operators__.add_12 (T  (None, 8, 8, 384)            0         ['tf.__operators__.add_11[0][0
#  FOpLambda)                                                         ]',
#                                                                      'convnext_tiny_stage_2_block_
#                                                                     6_identity[0][0]']
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 384)            19200     ['tf.__operators__.add_12[0][0
#  k_7_depthwise_conv (Conv2D                                         ]']
#  )
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 384)            768       ['convnext_tiny_stage_2_block_
#  k_7_layernorm (LayerNormal                                         7_depthwise_conv[0][0]']
#  ization)
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 1536)           591360    ['convnext_tiny_stage_2_block_
#  k_7_pointwise_conv_1 (Dens                                         7_layernorm[0][0]']
#  e)
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 1536)           0         ['convnext_tiny_stage_2_block_
#  k_7_gelu (Activation)                                              7_pointwise_conv_1[0][0]']
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 384)            590208    ['convnext_tiny_stage_2_block_
#  k_7_pointwise_conv_2 (Dens                                         7_gelu[0][0]']
#  e)
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 384)            384       ['convnext_tiny_stage_2_block_
#  k_7_layer_scale (LayerScal                                         7_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 384)            0         ['convnext_tiny_stage_2_block_
#  k_7_identity (Activation)                                          7_layer_scale[0][0]']
#
#  tf.__operators__.add_13 (T  (None, 8, 8, 384)            0         ['tf.__operators__.add_12[0][0
#  FOpLambda)                                                         ]',
#                                                                      'convnext_tiny_stage_2_block_
#                                                                     7_identity[0][0]']
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 384)            19200     ['tf.__operators__.add_13[0][0
#  k_8_depthwise_conv (Conv2D                                         ]']
#  )
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 384)            768       ['convnext_tiny_stage_2_block_
#  k_8_layernorm (LayerNormal                                         8_depthwise_conv[0][0]']
#  ization)
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 1536)           591360    ['convnext_tiny_stage_2_block_
#  k_8_pointwise_conv_1 (Dens                                         8_layernorm[0][0]']
#  e)
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 1536)           0         ['convnext_tiny_stage_2_block_
#  k_8_gelu (Activation)                                              8_pointwise_conv_1[0][0]']
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 384)            590208    ['convnext_tiny_stage_2_block_
#  k_8_pointwise_conv_2 (Dens                                         8_gelu[0][0]']
#  e)
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 384)            384       ['convnext_tiny_stage_2_block_
#  k_8_layer_scale (LayerScal                                         8_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 384)            0         ['convnext_tiny_stage_2_block_
#  k_8_identity (Activation)                                          8_layer_scale[0][0]']
#
#  tf.__operators__.add_14 (T  (None, 8, 8, 384)            0         ['tf.__operators__.add_13[0][0
#  FOpLambda)                                                         ]',
#                                                                      'convnext_tiny_stage_2_block_
#                                                                     8_identity[0][0]']
#
#  convnext_tiny_downsampling  (None, 4, 4, 768)            1181184   ['tf.__operators__.add_14[0][0
#  _block_2 (Sequential)                                              ]']
#
#  convnext_tiny_stage_3_bloc  (None, 4, 4, 768)            38400     ['convnext_tiny_downsampling_b
#  k_0_depthwise_conv (Conv2D                                         lock_2[0][0]']
#  )
#
#  convnext_tiny_stage_3_bloc  (None, 4, 4, 768)            1536      ['convnext_tiny_stage_3_block_
#  k_0_layernorm (LayerNormal                                         0_depthwise_conv[0][0]']
#  ization)
#
#  convnext_tiny_stage_3_bloc  (None, 4, 4, 3072)           2362368   ['convnext_tiny_stage_3_block_
#  k_0_pointwise_conv_1 (Dens                                         0_layernorm[0][0]']
#  e)
#
#  convnext_tiny_stage_3_bloc  (None, 4, 4, 3072)           0         ['convnext_tiny_stage_3_block_
#  k_0_gelu (Activation)                                              0_pointwise_conv_1[0][0]']
#
#  convnext_tiny_stage_3_bloc  (None, 4, 4, 768)            2360064   ['convnext_tiny_stage_3_block_
#  k_0_pointwise_conv_2 (Dens                                         0_gelu[0][0]']
#  e)
#
#  convnext_tiny_stage_3_bloc  (None, 4, 4, 768)            768       ['convnext_tiny_stage_3_block_
#  k_0_layer_scale (LayerScal                                         0_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_tiny_stage_3_bloc  (None, 4, 4, 768)            0         ['convnext_tiny_stage_3_block_
#  k_0_identity (Activation)                                          0_layer_scale[0][0]']
#
#  tf.__operators__.add_15 (T  (None, 4, 4, 768)            0         ['convnext_tiny_downsampling_b
#  FOpLambda)                                                         lock_2[0][0]',
#                                                                      'convnext_tiny_stage_3_block_
#                                                                     0_identity[0][0]']
#
#  convnext_tiny_stage_3_bloc  (None, 4, 4, 768)            38400     ['tf.__operators__.add_15[0][0
#  k_1_depthwise_conv (Conv2D                                         ]']
#  )
#
#  convnext_tiny_stage_3_bloc  (None, 4, 4, 768)            1536      ['convnext_tiny_stage_3_block_
#  k_1_layernorm (LayerNormal                                         1_depthwise_conv[0][0]']
#  ization)
#
#  convnext_tiny_stage_3_bloc  (None, 4, 4, 3072)           2362368   ['convnext_tiny_stage_3_block_
#  k_1_pointwise_conv_1 (Dens                                         1_layernorm[0][0]']
#  e)
#
#  convnext_tiny_stage_3_bloc  (None, 4, 4, 3072)           0         ['convnext_tiny_stage_3_block_
#  k_1_gelu (Activation)                                              1_pointwise_conv_1[0][0]']
#
#  convnext_tiny_stage_3_bloc  (None, 4, 4, 768)            2360064   ['convnext_tiny_stage_3_block_
#  k_1_pointwise_conv_2 (Dens                                         1_gelu[0][0]']
#  e)
#
#  convnext_tiny_stage_3_bloc  (None, 4, 4, 768)            768       ['convnext_tiny_stage_3_block_
#  k_1_layer_scale (LayerScal                                         1_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_tiny_stage_3_bloc  (None, 4, 4, 768)            0         ['convnext_tiny_stage_3_block_
#  k_1_identity (Activation)                                          1_layer_scale[0][0]']
#
#  tf.__operators__.add_16 (T  (None, 4, 4, 768)            0         ['tf.__operators__.add_15[0][0
#  FOpLambda)                                                         ]',
#                                                                      'convnext_tiny_stage_3_block_
#                                                                     1_identity[0][0]']
#
#  convnext_tiny_stage_3_bloc  (None, 4, 4, 768)            38400     ['tf.__operators__.add_16[0][0
#  k_2_depthwise_conv (Conv2D                                         ]']
#  )
#
#  convnext_tiny_stage_3_bloc  (None, 4, 4, 768)            1536      ['convnext_tiny_stage_3_block_
#  k_2_layernorm (LayerNormal                                         2_depthwise_conv[0][0]']
#  ization)
#
#  convnext_tiny_stage_3_bloc  (None, 4, 4, 3072)           2362368   ['convnext_tiny_stage_3_block_
#  k_2_pointwise_conv_1 (Dens                                         2_layernorm[0][0]']
#  e)
#
#  convnext_tiny_stage_3_bloc  (None, 4, 4, 3072)           0         ['convnext_tiny_stage_3_block_
#  k_2_gelu (Activation)                                              2_pointwise_conv_1[0][0]']
#
#  convnext_tiny_stage_3_bloc  (None, 4, 4, 768)            2360064   ['convnext_tiny_stage_3_block_
#  k_2_pointwise_conv_2 (Dens                                         2_gelu[0][0]']
#  e)
#
#  convnext_tiny_stage_3_bloc  (None, 4, 4, 768)            768       ['convnext_tiny_stage_3_block_
#  k_2_layer_scale (LayerScal                                         2_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_tiny_stage_3_bloc  (None, 4, 4, 768)            0         ['convnext_tiny_stage_3_block_
#  k_2_identity (Activation)                                          2_layer_scale[0][0]']
#
#  tf.__operators__.add_17 (T  (None, 4, 4, 768)            0         ['tf.__operators__.add_16[0][0
#  FOpLambda)                                                         ]',
#                                                                      'convnext_tiny_stage_3_block_
#                                                                     2_identity[0][0]']
#
#  layer_normalization (Layer  (None, 4, 4, 768)            1536      ['tf.__operators__.add_17[0][0
#  Normalization)                                                     ]']
#
#  global_average_pooling2d (  (None, 768)                  0         ['layer_normalization[0][0]']
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 125)                  96125     ['global_average_pooling2d[0][
#                                                                     0]']
#
#  dense_1 (Dense)             (None, 5)                    630       ['dense[0][0]']
#
# ==================================================================================================
# Total params: 27916883 (106.49 MB)
# Trainable params: 27916883 (106.49 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
classification_model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Define callbacks
checkpoint = ModelCheckpoint("/content/drive/MyDrive/NF/convnext.h5", monitor='val_loss', verbose=1, save_best_only=True, mode='min')
early_stopping = EarlyStopping(monitor='val_loss', patience=7, verbose=1, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=1e-6, verbose=1)

# Train the model
history = classification_model.fit(x_train, y_train, epochs=25, batch_size=32, validation_data=(x_test, y_test), callbacks=[checkpoint, early_stopping, reduce_lr])
# Out:
# Epoch 1/25
# 69/69 [==============================] - ETA: 0s - loss: 1.2849 - accuracy: 0.4414
# Epoch 1: val_loss improved from inf to 0.94228, saving model to /content/drive/MyDrive/NF/convnext.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 69/69 [==============================] - 70s 405ms/step - loss: 1.2849 - accuracy: 0.4414 - val_loss: 0.9423 - val_accuracy: 0.6400 - lr: 0.0010
# Epoch 2/25
# 69/69 [==============================] - ETA: 0s - loss: 0.8928 - accuracy: 0.6359
# Epoch 2: val_loss improved from 0.94228 to 0.85350, saving model to /content/drive/MyDrive/NF/convnext.h5
# 69/69 [==============================] - 24s 349ms/step - loss: 0.8928 - accuracy: 0.6359 - val_loss: 0.8535 - val_accuracy: 0.6545 - lr: 0.0010
# Epoch 3/25
# 69/69 [==============================] - ETA: 0s - loss: 0.7121 - accuracy: 0.7100
# Epoch 3: val_loss improved from 0.85350 to 0.69582, saving model to /content/drive/MyDrive/NF/convnext.h5
# 69/69 [==============================] - 23s 328ms/step - loss: 0.7121 - accuracy: 0.7100 - val_loss: 0.6958 - val_accuracy: 0.6964 - lr: 0.0010
# Epoch 4/25
# 69/69 [==============================] - ETA: 0s - loss: 0.5197 - accuracy: 0.7909
# Epoch 4: val_loss improved from 0.69582 to 0.50019, saving model to /content/drive/MyDrive/NF/convnext.h5
# 69/69 [==============================] - 21s 311ms/step - loss: 0.5197 - accuracy: 0.7909 - val_loss: 0.5002 - val_accuracy: 0.7909 - lr: 0.0010
# Epoch 5/25
# 69/69 [==============================] - ETA: 0s - loss: 0.4461 - accuracy: 0.8200
# Epoch 5: val_loss did not improve from 0.50019
# 69/69 [==============================] - 18s 264ms/step - loss: 0.4461 - accuracy: 0.8200 - val_loss: 0.5758 - val_accuracy: 0.7618 - lr: 0.0010
# Epoch 6/25
# 69/69 [==============================] - ETA: 0s - loss: 0.3376 - accuracy: 0.8750
# Epoch 6: val_loss improved from 0.50019 to 0.49915, saving model to /content/drive/MyDrive/NF/convnext.h5
# 69/69 [==============================] - 23s 338ms/step - loss: 0.3376 - accuracy: 0.8750 - val_loss: 0.4992 - val_accuracy: 0.8073 - lr: 0.0010
# Epoch 7/25
# 69/69 [==============================] - ETA: 0s - loss: 0.2512 - accuracy: 0.9068
# Epoch 7: val_loss improved from 0.49915 to 0.33433, saving model to /content/drive/MyDrive/NF/convnext.h5
# 69/69 [==============================] - 24s 356ms/step - loss: 0.2512 - accuracy: 0.9068 - val_loss: 0.3343 - val_accuracy: 0.8764 - lr: 0.0010
# Epoch 8/25
# 69/69 [==============================] - ETA: 0s - loss: 0.2233 - accuracy: 0.9173
# Epoch 8: val_loss did not improve from 0.33433
# 69/69 [==============================] - 18s 267ms/step - loss: 0.2233 - accuracy: 0.9173 - val_loss: 0.3969 - val_accuracy: 0.8309 - lr: 0.0010
# Epoch 9/25
# 69/69 [==============================] - ETA: 0s - loss: 0.1880 - accuracy: 0.9323
# Epoch 9: val_loss did not improve from 0.33433
# 69/69 [==============================] - 18s 265ms/step - loss: 0.1880 - accuracy: 0.9323 - val_loss: 0.4069 - val_accuracy: 0.8473 - lr: 0.0010
# Epoch 10/25
# 69/69 [==============================] - ETA: 0s - loss: 0.1931 - accuracy: 0.9341
# Epoch 10: val_loss did not improve from 0.33433
# 69/69 [==============================] - 18s 264ms/step - loss: 0.1931 - accuracy: 0.9341 - val_loss: 0.4860 - val_accuracy: 0.8382 - lr: 0.0010
# Epoch 11/25
# 69/69 [==============================] - ETA: 0s - loss: 0.2384 - accuracy: 0.9218
# Epoch 11: val_loss improved from 0.33433 to 0.27986, saving model to /content/drive/MyDrive/NF/convnext.h5
# 69/69 [==============================] - 23s 335ms/step - loss: 0.2384 - accuracy: 0.9218 - val_loss: 0.2799 - val_accuracy: 0.9091 - lr: 0.0010
# Epoch 12/25
# 69/69 [==============================] - ETA: 0s - loss: 0.0770 - accuracy: 0.9759
# Epoch 12: val_loss did not improve from 0.27986
# 69/69 [==============================] - 19s 269ms/step - loss: 0.0770 - accuracy: 0.9759 - val_loss: 0.3371 - val_accuracy: 0.8709 - lr: 0.0010
# Epoch 13/25
# 69/69 [==============================] - ETA: 0s - loss: 0.0921 - accuracy: 0.9695
# Epoch 13: val_loss did not improve from 0.27986
# 69/69 [==============================] - 18s 265ms/step - loss: 0.0921 - accuracy: 0.9695 - val_loss: 0.4060 - val_accuracy: 0.8655 - lr: 0.0010
# Epoch 14/25
# 69/69 [==============================] - ETA: 0s - loss: 0.0937 - accuracy: 0.9691
# Epoch 14: val_loss did not improve from 0.27986
# 69/69 [==============================] - 17s 250ms/step - loss: 0.0937 - accuracy: 0.9691 - val_loss: 0.2847 - val_accuracy: 0.8982 - lr: 0.0010
# Epoch 15/25
# 69/69 [==============================] - ETA: 0s - loss: 0.0604 - accuracy: 0.9818
# Epoch 15: val_loss did not improve from 0.27986
# 69/69 [==============================] - 18s 264ms/step - loss: 0.0604 - accuracy: 0.9818 - val_loss: 0.6427 - val_accuracy: 0.8218 - lr: 0.0010
# Epoch 16/25
# 69/69 [==============================] - ETA: 0s - loss: 0.1501 - accuracy: 0.9523
# Epoch 16: val_loss did not improve from 0.27986
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 69/69 [==============================] - 18s 263ms/step - loss: 0.1501 - accuracy: 0.9523 - val_loss: 0.4168 - val_accuracy: 0.8673 - lr: 0.0010
# Epoch 17/25
# 69/69 [==============================] - ETA: 0s - loss: 0.0194 - accuracy: 0.9955
# Epoch 17: val_loss improved from 0.27986 to 0.23913, saving model to /content/drive/MyDrive/NF/convnext.h5
# 69/69 [==============================] - 22s 317ms/step - loss: 0.0194 - accuracy: 0.9955 - val_loss: 0.2391 - val_accuracy: 0.9218 - lr: 2.0000e-04
# Epoch 18/25
# 69/69 [==============================] - ETA: 0s - loss: 0.0065 - accuracy: 1.0000
# Epoch 18: val_loss improved from 0.23913 to 0.23597, saving model to /content/drive/MyDrive/NF/convnext.h5
# 69/69 [==============================] - 23s 338ms/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 0.2360 - val_accuracy: 0.9273 - lr: 2.0000e-04
# Epoch 19/25
# 69/69 [==============================] - ETA: 0s - loss: 0.0052 - accuracy: 1.0000
# Epoch 19: val_loss did not improve from 0.23597
# 69/69 [==============================] - 17s 250ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.2416 - val_accuracy: 0.9273 - lr: 2.0000e-04
# Epoch 20/25
# 69/69 [==============================] - ETA: 0s - loss: 0.0045 - accuracy: 1.0000
# Epoch 20: val_loss did not improve from 0.23597
# 69/69 [==============================] - 18s 266ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.2441 - val_accuracy: 0.9291 - lr: 2.0000e-04
# Epoch 21/25
# 69/69 [==============================] - ETA: 0s - loss: 0.0039 - accuracy: 1.0000
# Epoch 21: val_loss did not improve from 0.23597
# 69/69 [==============================] - 18s 264ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.2472 - val_accuracy: 0.9327 - lr: 2.0000e-04
# Epoch 22/25
# 69/69 [==============================] - ETA: 0s - loss: 0.0035 - accuracy: 1.0000
# Epoch 22: val_loss did not improve from 0.23597
# 69/69 [==============================] - 17s 250ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.2565 - val_accuracy: 0.9327 - lr: 2.0000e-04
# Epoch 23/25
# 69/69 [==============================] - ETA: 0s - loss: 0.0031 - accuracy: 1.0000
# Epoch 23: val_loss did not improve from 0.23597
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 69/69 [==============================] - 18s 264ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.2638 - val_accuracy: 0.9291 - lr: 2.0000e-04
# Epoch 24/25
# 69/69 [==============================] - ETA: 0s - loss: 0.0029 - accuracy: 1.0000
# Epoch 24: val_loss did not improve from 0.23597
# 69/69 [==============================] - 17s 249ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.2661 - val_accuracy: 0.9309 - lr: 4.0000e-05
# Epoch 25/25
# 69/69 [==============================] - ETA: 0s - loss: 0.0028 - accuracy: 1.0000
# Epoch 25: val_loss did not improve from 0.23597
# Restoring model weights from the end of the best epoch: 18.
# 69/69 [==============================] - 18s 267ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.2676 - val_accuracy: 0.9309 - lr: 4.0000e-05
# Epoch 25: early stopping

# %%
classification_model.load_weights("/content/drive/MyDrive/NF/convnext.h5")
classification_model.evaluate(x_test, y_test)
# Out:
# 18/18 [==============================] - 2s 81ms/step - loss: 0.2360 - accuracy: 0.9273
# [0.23597398400306702, 0.9272727370262146]

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

# Assuming classification_model.predict returns probabilities or predicted classes
y_pred = classification_model.predict(x_test)

# If y_pred contains probabilities, you may want to convert them to classes
# For binary classification:
# y_pred_classes = (y_pred > 0.5).astype(int)

# For multi-class classification with softmax output:
y_pred_classes = np.argmax(y_pred, axis=1)
from sklearn.metrics import classification_report

# Assuming y_pred_classes are predicted classes

# Generate classification report
report = classification_report(y_test, y_pred_classes, digits=5)

# Print the report
print("Classification Report:")
print(report)
# Out:
# 18/18 [==============================] - 3s 80ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0    0.98077   0.93578   0.95775       109
#            1    0.99107   0.94872   0.96943       117
#            2    0.86726   0.95146   0.90741       103
#            3    0.88496   0.88496   0.88496       113
#            4    0.91667   0.91667   0.91667       108
#
#     accuracy                        0.92727       550
#    macro avg    0.92814   0.92752   0.92724       550
# weighted avg    0.92943   0.92727   0.92778       550

# %%
# Visualize t-SNE embeddings
# Assuming x_train_embed and x_test_embed are the embeddings obtained from the penultimate layer
tsne = TSNE(n_components=2, random_state=42)
x_embed = base_model.predict(x_test)  # Assuming x_test is your test data
x_tsne = tsne.fit_transform(x_embed)

# Plot t-SNE embeddings
plt.figure(figsize=(10, 8))
plt.scatter(x_tsne[:, 0], x_tsne[:, 1], c=y_test, cmap='viridis')
plt.colorbar()
plt.title(' Test t-SNE Embeddings')
plt.xlabel('t-SNE Component 1')
plt.ylabel('t-SNE Component 2')
plt.show()
# Out:
# 18/18 [==============================] - 3s 77ms/step

# %%
# Visualize t-SNE embeddings
# Assuming x_train_embed and x_test_embed are the embeddings obtained from the penultimate layer
x_test_flat = x_test.reshape((550, 128*128*3))
tsne = TSNE(n_components=2, random_state=42)
#x_embed = base_model.predict(x_test)  # Assuming x_test is your test data
x_tsne = tsne.fit_transform(x_test_flat)

# Plot t-SNE embeddings
plt.figure(figsize=(10, 8))
plt.scatter(x_tsne[:, 0], x_tsne[:, 1], c=y_test, cmap='viridis')
plt.colorbar()
plt.title(' Test Images')
plt.xlabel('t-SNE Component 1')
plt.ylabel('t-SNE Component 2')
plt.show()

# %%
# Visualize t-SNE embeddings
# Assuming x_train_embed and x_train_embed are the embeddings obtained from the penultimate layer
x_train_flat = x_train.reshape((2200, 128*128*3))
tsne = TSNE(n_components=2, random_state=42)
#x_embed = base_model.predict(x_train)  # Assuming x_train is your train data
x_tsne = tsne.fit_transform(x_train_flat)

# Plot t-SNE embeddings
plt.figure(figsize=(10, 8))
plt.scatter(x_tsne[:, 0], x_tsne[:, 1], c=y_train, cmap='viridis')
plt.colorbar()
plt.title('Train Images')
plt.xlabel('t-SNE Component 1')
plt.ylabel('t-SNE Component 2')
plt.show()

# %%
# Visualize t-SNE embeddings
# Assuming x_train_embed and x_train_embed are the embeddings obtained from the penultimate layer
tsne = TSNE(n_components=2, random_state=42)
x_embed = base_model.predict(x_train)  # Assuming x_train is your train data
x_tsne = tsne.fit_transform(x_embed)

# Plot t-SNE embeddings
plt.figure(figsize=(10, 8))
plt.scatter(x_tsne[:, 0], x_tsne[:, 1], c=y_train, cmap='viridis')
plt.colorbar()
plt.title('Train t-SNE Embeddings')
plt.xlabel('t-SNE Component 1')
plt.ylabel('t-SNE Component 2')
plt.show()
# Out:
# 69/69 [==============================] - 7s 108ms/step

# %% [markdown]
# <h1>E-Mixup

# %%
xtest_emb = base_model.predict(x_test)
xtrain_emb = base_model.predict(x_train)
# Out:
# 18/18 [==============================] - 2s 87ms/step
# 69/69 [==============================] - 6s 81ms/step

# %%
import keras
y_test_o = keras.utils.to_categorical(y_test)
y_train_o = keras.utils.to_categorical(y_train)
print(y_train_o.shape)
print(y_test_o.shape)
# Out:
# (2200, 5)
# (550, 5)

# %%
def mixup(xt, yt, mf):
  alp = 0.2
  xaug = []
  yaug = []
  for k in range(0,xt.shape[0]):
    cnt = 0
    for cnt in range(0,mf-1):
      lbd = np.random.beta(alp,alp)
      yks = np.random.randint(xt.shape[0])
      kdash = xt[yks]
      ydash = yt[yks]
      kdash1 = xt[k]
      ydash1 = yt[k]
      xaug1 = kdash1*lbd + kdash*(1-lbd)
      yaug1 = ydash1*lbd + ydash*(1-lbd)
      xaug.append(xaug1)
      yaug.append(yaug1)
  xs2 = np.asarray(xaug)
  ys2 = np.asarray(yaug)
  x1 = np.concatenate((xt,xs2))
  y1 = np.concatenate((yt,ys2))
  return x1,y1

# %%
xtrain_emb.shape
# Out:
# (2200, 125)

# %%
xtt, ytt = mixup(xtrain_emb,y_train_o,3)
xtt.shape
# Out:
# (6600, 125)

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
import tensorflow as tf

Classifier_model = Sequential()
#add model layers
Classifier_model.Input = (125,)

Classifier_model.add(Dense(512,activation='relu'))
Classifier_model.add(Dense(512,activation='relu'))

Classifier_model.add(Dense(5, activation='softmax'))
opt = tf.keras.optimizers.Adam(learning_rate=0.001)
Classifier_model.compile(optimizer=opt,loss='categorical_crossentropy',metrics=['accuracy'])
Classifier_model.fit(xtt, ytt,epochs=25, validation_data=(xtest_emb, y_test_o))
# Out:
# Epoch 1/25
# 207/207 [==============================] - 3s 5ms/step - loss: 0.1970 - accuracy: 0.9865 - val_loss: 0.2334 - val_accuracy: 0.9255
# Epoch 2/25
# 207/207 [==============================] - 1s 3ms/step - loss: 0.1559 - accuracy: 0.9886 - val_loss: 0.2518 - val_accuracy: 0.9236
# Epoch 3/25
# 207/207 [==============================] - 1s 4ms/step - loss: 0.1469 - accuracy: 0.9891 - val_loss: 0.2560 - val_accuracy: 0.9218
# Epoch 4/25
# 207/207 [==============================] - 1s 5ms/step - loss: 0.1426 - accuracy: 0.9895 - val_loss: 0.2800 - val_accuracy: 0.9236
# Epoch 5/25
# 207/207 [==============================] - 1s 5ms/step - loss: 0.1401 - accuracy: 0.9883 - val_loss: 0.2933 - val_accuracy: 0.9127
# Epoch 6/25
# 207/207 [==============================] - 1s 3ms/step - loss: 0.1385 - accuracy: 0.9900 - val_loss: 0.3093 - val_accuracy: 0.9182
# Epoch 7/25
# 207/207 [==============================] - 1s 3ms/step - loss: 0.1362 - accuracy: 0.9895 - val_loss: 0.2859 - val_accuracy: 0.9236
# Epoch 8/25
# 207/207 [==============================] - 1s 3ms/step - loss: 0.1347 - accuracy: 0.9902 - val_loss: 0.3033 - val_accuracy: 0.9109
# Epoch 9/25
# 207/207 [==============================] - 1s 3ms/step - loss: 0.1335 - accuracy: 0.9917 - val_loss: 0.3020 - val_accuracy: 0.9182
# Epoch 10/25
# 207/207 [==============================] - 1s 3ms/step - loss: 0.1323 - accuracy: 0.9920 - val_loss: 0.3066 - val_accuracy: 0.9200
# Epoch 11/25
# 207/207 [==============================] - 1s 3ms/step - loss: 0.1322 - accuracy: 0.9923 - val_loss: 0.3293 - val_accuracy: 0.9164
# Epoch 12/25
# 207/207 [==============================] - 1s 3ms/step - loss: 0.1312 - accuracy: 0.9926 - val_loss: 0.3216 - val_accuracy: 0.9200
# Epoch 13/25
# 207/207 [==============================] - 1s 3ms/step - loss: 0.1306 - accuracy: 0.9939 - val_loss: 0.3375 - val_accuracy: 0.9127
# Epoch 14/25
# 207/207 [==============================] - 1s 3ms/step - loss: 0.1318 - accuracy: 0.9923 - val_loss: 0.3191 - val_accuracy: 0.9164
# Epoch 15/25
# 207/207 [==============================] - 1s 3ms/step - loss: 0.1295 - accuracy: 0.9945 - val_loss: 0.3098 - val_accuracy: 0.9182
# Epoch 16/25
# 207/207 [==============================] - 1s 3ms/step - loss: 0.1297 - accuracy: 0.9936 - val_loss: 0.3328 - val_accuracy: 0.9164
# Epoch 17/25
# 207/207 [==============================] - 1s 3ms/step - loss: 0.1296 - accuracy: 0.9938 - val_loss: 0.3801 - val_accuracy: 0.9145
# Epoch 18/25
# 207/207 [==============================] - 1s 3ms/step - loss: 0.1291 - accuracy: 0.9936 - val_loss: 0.3267 - val_accuracy: 0.9182
# Epoch 19/25
# 207/207 [==============================] - 1s 3ms/step - loss: 0.1290 - accuracy: 0.9936 - val_loss: 0.3584 - val_accuracy: 0.9145
# Epoch 20/25
# 207/207 [==============================] - 1s 4ms/step - loss: 0.1294 - accuracy: 0.9929 - val_loss: 0.3304 - val_accuracy: 0.9164
# Epoch 21/25
# 207/207 [==============================] - 1s 4ms/step - loss: 0.1285 - accuracy: 0.9948 - val_loss: 0.3583 - val_accuracy: 0.9164
# Epoch 22/25
# 207/207 [==============================] - 1s 5ms/step - loss: 0.1276 - accuracy: 0.9939 - val_loss: 0.3695 - val_accuracy: 0.9145
# Epoch 23/25
# 207/207 [==============================] - 1s 4ms/step - loss: 0.1285 - accuracy: 0.9932 - val_loss: 0.3935 - val_accuracy: 0.9145
# Epoch 24/25
# 207/207 [==============================] - 1s 3ms/step - loss: 0.1281 - accuracy: 0.9944 - val_loss: 0.3539 - val_accuracy: 0.9182
# Epoch 25/25
# 207/207 [==============================] - 1s 3ms/step - loss: 0.1275 - accuracy: 0.9948 - val_loss: 0.3810 - val_accuracy: 0.9164

# %%
Classifier_model.evaluate(xtest_emb, y_test_o)
# Out:
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3810 - accuracy: 0.9164
# [0.3809680640697479, 0.9163636565208435]

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

# Assuming Classifier_model.predict returns probabilities or predicted classes
y_pred = Classifier_model.predict(xtest_emb)

# If y_pred contains probabilities, you may want to convert them to classes
# For binary classification:
# y_pred_classes = (y_pred > 0.5).astype(int)
# For multi-class classification with softmax output:
y_pred_classes = np.argmax(y_pred, axis=1)
from sklearn.metrics import classification_report

# Assuming y_pred_classes are predicted classes

# Generate classification report
report = classification_report(y_test, y_pred_classes, digits=5)

# Print the report
print("Classification Report:")
print(report)
# Out:
# 18/18 [==============================] - 0s 1ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0    0.98000   0.89908   0.93780       109
#            1    0.99115   0.95726   0.97391       117
#            2    0.85714   0.93204   0.89302       103
#            3    0.86957   0.88496   0.87719       113
#            4    0.89091   0.90741   0.89908       108
#
#     accuracy                        0.91636       550
#    macro avg    0.91775   0.91615   0.91620       550
# weighted avg    0.91918   0.91636   0.91704       550

# %% [markdown]
# E-Stitchup

# %%
import numpy as np

def stichup(xt, yt, mf):
    alp = 0.2
    xaug = []
    yaug = []
    for k in range(xt.shape[0]):
        for _ in range(mf-1):  # Renamed loop counter to avoid confusion with loop index
            lbd = np.random.beta(alp, alp)
            yks = np.random.randint(xt.shape[0])
            kdash = xt[yks]  # Accessing rows of xt directly
            ydash = yt[yks]  # Accessing corresponding y value
            kdash1 = xt[k]    # Accessing rows of xt directly
            ydash1 = yt[k]    # Accessing corresponding y value
            lbd_stch = int(xt.shape[1] * lbd)
            reff_stich = np.zeros(xt.shape[1])
            for i in range(lbd_stch):
                index_stich = np.random.randint(xt.shape[1])
                reff_stich[index_stich] = 1
            xaug1 = np.zeros(xt.shape[1])  # Initialize as numpy array
            for i in range(len(reff_stich)):
                if reff_stich[i] == 0:
                    xaug1[i] = kdash[i]
                else:
                    xaug1[i] = kdash1[i]
            yaug1 = ydash1 * lbd + ydash * (1 - lbd)
            xaug.append(xaug1)
            yaug.append(yaug1)
    xs2 = np.asarray(xaug)
    ys2 = np.asarray(yaug)
    x1 = np.concatenate((xt, xs2))
    y1 = np.concatenate((yt, ys2))
    return x1, y1

# %%
xtt, ytt = stichup(xtrain_emb,y_train_o,3)
xtt.shape
# Out:
# (6600, 125)

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
import tensorflow as tf

Classifier_model = Sequential()
#add model layers
Classifier_model.Input = (125,)

Classifier_model.add(Dense(512,activation='relu'))
Classifier_model.add(Dense(512,activation='relu'))

Classifier_model.add(Dense(5, activation='softmax'))
opt = tf.keras.optimizers.Adam(learning_rate=0.001)
Classifier_model.compile(optimizer=opt,loss='categorical_crossentropy',metrics=['accuracy'])
Classifier_model.fit(xtt, ytt,epochs=25, validation_data=(xtest_emb, y_test_o))
# Out:
# Epoch 1/25
# 207/207 [==============================] - 2s 4ms/step - loss: 0.2634 - accuracy: 0.9432 - val_loss: 0.2617 - val_accuracy: 0.9164
# Epoch 2/25
# 207/207 [==============================] - 1s 3ms/step - loss: 0.2228 - accuracy: 0.9564 - val_loss: 0.2331 - val_accuracy: 0.9255
# Epoch 3/25
# 207/207 [==============================] - 1s 3ms/step - loss: 0.2175 - accuracy: 0.9559 - val_loss: 0.2651 - val_accuracy: 0.9200
# Epoch 4/25
# 207/207 [==============================] - 1s 3ms/step - loss: 0.2094 - accuracy: 0.9612 - val_loss: 0.2814 - val_accuracy: 0.9218
# Epoch 5/25
# 207/207 [==============================] - 1s 3ms/step - loss: 0.2042 - accuracy: 0.9635 - val_loss: 0.2726 - val_accuracy: 0.9164
# Epoch 6/25
# 207/207 [==============================] - 1s 3ms/step - loss: 0.1969 - accuracy: 0.9648 - val_loss: 0.2738 - val_accuracy: 0.9218
# Epoch 7/25
# 207/207 [==============================] - 1s 3ms/step - loss: 0.1907 - accuracy: 0.9685 - val_loss: 0.2793 - val_accuracy: 0.9218
# Epoch 8/25
# 207/207 [==============================] - 1s 3ms/step - loss: 0.1883 - accuracy: 0.9694 - val_loss: 0.2734 - val_accuracy: 0.9236
# Epoch 9/25
# 207/207 [==============================] - 1s 5ms/step - loss: 0.1797 - accuracy: 0.9736 - val_loss: 0.2706 - val_accuracy: 0.9200
# Epoch 10/25
# 207/207 [==============================] - 1s 5ms/step - loss: 0.1732 - accuracy: 0.9777 - val_loss: 0.2889 - val_accuracy: 0.9255
# Epoch 11/25
# 207/207 [==============================] - 1s 5ms/step - loss: 0.1688 - accuracy: 0.9747 - val_loss: 0.2827 - val_accuracy: 0.9255
# Epoch 12/25
# 207/207 [==============================] - 1s 3ms/step - loss: 0.1648 - accuracy: 0.9791 - val_loss: 0.3267 - val_accuracy: 0.9218
# Epoch 13/25
# 207/207 [==============================] - 1s 3ms/step - loss: 0.1603 - accuracy: 0.9815 - val_loss: 0.2787 - val_accuracy: 0.9291
# Epoch 14/25
# 207/207 [==============================] - 1s 3ms/step - loss: 0.1545 - accuracy: 0.9832 - val_loss: 0.2985 - val_accuracy: 0.9236
# Epoch 15/25
# 207/207 [==============================] - 1s 3ms/step - loss: 0.1549 - accuracy: 0.9820 - val_loss: 0.3114 - val_accuracy: 0.9200
# Epoch 16/25
# 207/207 [==============================] - 1s 3ms/step - loss: 0.1534 - accuracy: 0.9812 - val_loss: 0.3156 - val_accuracy: 0.9236
# Epoch 17/25
# 207/207 [==============================] - 1s 3ms/step - loss: 0.1494 - accuracy: 0.9798 - val_loss: 0.3191 - val_accuracy: 0.9182
# Epoch 18/25
# 207/207 [==============================] - 1s 3ms/step - loss: 0.1487 - accuracy: 0.9806 - val_loss: 0.3339 - val_accuracy: 0.9218
# Epoch 19/25
# 207/207 [==============================] - 1s 3ms/step - loss: 0.1472 - accuracy: 0.9798 - val_loss: 0.3193 - val_accuracy: 0.9218
# Epoch 20/25
# 207/207 [==============================] - 1s 3ms/step - loss: 0.1460 - accuracy: 0.9805 - val_loss: 0.3393 - val_accuracy: 0.9182
# Epoch 21/25
# 207/207 [==============================] - 1s 3ms/step - loss: 0.1477 - accuracy: 0.9798 - val_loss: 0.3370 - val_accuracy: 0.9218
# Epoch 22/25
# 207/207 [==============================] - 1s 3ms/step - loss: 0.1460 - accuracy: 0.9835 - val_loss: 0.3236 - val_accuracy: 0.9200
# Epoch 23/25
# 207/207 [==============================] - 1s 3ms/step - loss: 0.1433 - accuracy: 0.9800 - val_loss: 0.3304 - val_accuracy: 0.9182
# Epoch 24/25
# 207/207 [==============================] - 1s 3ms/step - loss: 0.1439 - accuracy: 0.9820 - val_loss: 0.3277 - val_accuracy: 0.9255
# Epoch 25/25
# 207/207 [==============================] - 1s 3ms/step - loss: 0.1443 - accuracy: 0.9795 - val_loss: 0.3490 - val_accuracy: 0.9218

# %%
Classifier_model.evaluate(xtest_emb, y_test_o)
# Out:
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3490 - accuracy: 0.9218
# [0.3489740788936615, 0.921818196773529]

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

# Assuming Classifier_model.predict returns probabilities or predicted classes
y_pred = Classifier_model.predict(xtest_emb)

# If y_pred contains probabilities, you may want to convert them to classes
# For binary classification:
# y_pred_classes = (y_pred > 0.5).astype(int)
# For multi-class classification with softmax output:
y_pred_classes = np.argmax(y_pred, axis=1)
from sklearn.metrics import classification_report

# Assuming y_pred_classes are predicted classes

# Generate classification report
report = classification_report(y_test, y_pred_classes, digits=5)

# Print the report
print("Classification Report:")
print(report)
# Out:
# 18/18 [==============================] - 0s 2ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0    0.99020   0.92661   0.95735       109
#            1    0.99099   0.94017   0.96491       117
#            2    0.85217   0.95146   0.89908       103
#            3    0.87611   0.87611   0.87611       113
#            4    0.90826   0.91667   0.91244       108
#
#     accuracy                        0.92182       550
#    macro avg    0.92354   0.92220   0.92198       550
# weighted avg    0.92499   0.92182   0.92254       550
