# %%
import numpy as np
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
from keras.models import Model
from keras.layers import Dense, GlobalAveragePooling2D
from keras.applications import DenseNet121
from sklearn.model_selection import train_test_split

# %%
x = np.load('/content/drive/MyDrive/N/resized_images.npy')
y = np.load('/content/drive/MyDrive/N/labels.npy')

# Perform train-test split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=7)

# Create DenseNet base
input_shape = x_train.shape[1:]  # Assuming x_train is a numpy array of images
input_shape
# Out:
# (128, 128, 3)

# %%
print(x_train.shape)
print(x_test.shape)
# Out:
# (2200, 128, 128, 3)
# (550, 128, 128, 3)

# %%
from tensorflow.keras.applications import ConvNeXtTiny
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.models import Model

def create_ConvNeXtTiny_base(input_shape):
    # Load ConvNeXtTiny model without the top layer
    base_model = ConvNeXtTiny(include_top=False, input_shape=input_shape)

    # Perform global average pooling
    x = base_model.output
    x = GlobalAveragePooling2D()(x)

    # Add a dense layer with 125 sigmoid activated neurons
    x = Dense(125, activation='sigmoid')(x)

    model = Model(inputs=base_model.input, outputs=x)
    return model

def create_classification_model(base_model, num_classes):
    # Freeze the base model layers
    for layer in base_model.layers:
        layer.trainable = True

    # Add a dense layer with softmax activation for classification
    x = Dense(num_classes, activation='softmax')(base_model.output)

    # Create the classification model
    model = Model(inputs=base_model.input, outputs=x)

    return model

base_model = create_ConvNeXtTiny_base(input_shape)

num_classes = 5  # Change this to the number of classes in your classification task
classification_model = create_classification_model(base_model, num_classes)

classification_model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/convnext/convnext_tiny_notop.h5
# 111650432/111650432 [==============================] - 5s 0us/step
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 128, 128, 3)]        0         []
#
#  convnext_tiny_prestem_norm  (None, 128, 128, 3)          0         ['input_1[0][0]']
#  alization (Normalization)
#
#  convnext_tiny_stem (Sequen  (None, 32, 32, 96)           4896      ['convnext_tiny_prestem_normal
#  tial)                                                              ization[0][0]']
#
#  convnext_tiny_stage_0_bloc  (None, 32, 32, 96)           4800      ['convnext_tiny_stem[0][0]']
#  k_0_depthwise_conv (Conv2D
#  )
#
#  convnext_tiny_stage_0_bloc  (None, 32, 32, 96)           192       ['convnext_tiny_stage_0_block_
#  k_0_layernorm (LayerNormal                                         0_depthwise_conv[0][0]']
#  ization)
#
#  convnext_tiny_stage_0_bloc  (None, 32, 32, 384)          37248     ['convnext_tiny_stage_0_block_
#  k_0_pointwise_conv_1 (Dens                                         0_layernorm[0][0]']
#  e)
#
#  convnext_tiny_stage_0_bloc  (None, 32, 32, 384)          0         ['convnext_tiny_stage_0_block_
#  k_0_gelu (Activation)                                              0_pointwise_conv_1[0][0]']
#
#  convnext_tiny_stage_0_bloc  (None, 32, 32, 96)           36960     ['convnext_tiny_stage_0_block_
#  k_0_pointwise_conv_2 (Dens                                         0_gelu[0][0]']
#  e)
#
#  convnext_tiny_stage_0_bloc  (None, 32, 32, 96)           96        ['convnext_tiny_stage_0_block_
#  k_0_layer_scale (LayerScal                                         0_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_tiny_stage_0_bloc  (None, 32, 32, 96)           0         ['convnext_tiny_stage_0_block_
#  k_0_identity (Activation)                                          0_layer_scale[0][0]']
#
#  tf.__operators__.add (TFOp  (None, 32, 32, 96)           0         ['convnext_tiny_stem[0][0]',
#  Lambda)                                                             'convnext_tiny_stage_0_block_
#                                                                     0_identity[0][0]']
#
#  convnext_tiny_stage_0_bloc  (None, 32, 32, 96)           4800      ['tf.__operators__.add[0][0]']
#  k_1_depthwise_conv (Conv2D
#  )
#
#  convnext_tiny_stage_0_bloc  (None, 32, 32, 96)           192       ['convnext_tiny_stage_0_block_
#  k_1_layernorm (LayerNormal                                         1_depthwise_conv[0][0]']
#  ization)
#
#  convnext_tiny_stage_0_bloc  (None, 32, 32, 384)          37248     ['convnext_tiny_stage_0_block_
#  k_1_pointwise_conv_1 (Dens                                         1_layernorm[0][0]']
#  e)
#
#  convnext_tiny_stage_0_bloc  (None, 32, 32, 384)          0         ['convnext_tiny_stage_0_block_
#  k_1_gelu (Activation)                                              1_pointwise_conv_1[0][0]']
#
#  convnext_tiny_stage_0_bloc  (None, 32, 32, 96)           36960     ['convnext_tiny_stage_0_block_
#  k_1_pointwise_conv_2 (Dens                                         1_gelu[0][0]']
#  e)
#
#  convnext_tiny_stage_0_bloc  (None, 32, 32, 96)           96        ['convnext_tiny_stage_0_block_
#  k_1_layer_scale (LayerScal                                         1_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_tiny_stage_0_bloc  (None, 32, 32, 96)           0         ['convnext_tiny_stage_0_block_
#  k_1_identity (Activation)                                          1_layer_scale[0][0]']
#
#  tf.__operators__.add_1 (TF  (None, 32, 32, 96)           0         ['tf.__operators__.add[0][0]',
#  OpLambda)                                                           'convnext_tiny_stage_0_block_
#                                                                     1_identity[0][0]']
#
#  convnext_tiny_stage_0_bloc  (None, 32, 32, 96)           4800      ['tf.__operators__.add_1[0][0]
#  k_2_depthwise_conv (Conv2D                                         ']
#  )
#
#  convnext_tiny_stage_0_bloc  (None, 32, 32, 96)           192       ['convnext_tiny_stage_0_block_
#  k_2_layernorm (LayerNormal                                         2_depthwise_conv[0][0]']
#  ization)
#
#  convnext_tiny_stage_0_bloc  (None, 32, 32, 384)          37248     ['convnext_tiny_stage_0_block_
#  k_2_pointwise_conv_1 (Dens                                         2_layernorm[0][0]']
#  e)
#
#  convnext_tiny_stage_0_bloc  (None, 32, 32, 384)          0         ['convnext_tiny_stage_0_block_
#  k_2_gelu (Activation)                                              2_pointwise_conv_1[0][0]']
#
#  convnext_tiny_stage_0_bloc  (None, 32, 32, 96)           36960     ['convnext_tiny_stage_0_block_
#  k_2_pointwise_conv_2 (Dens                                         2_gelu[0][0]']
#  e)
#
#  convnext_tiny_stage_0_bloc  (None, 32, 32, 96)           96        ['convnext_tiny_stage_0_block_
#  k_2_layer_scale (LayerScal                                         2_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_tiny_stage_0_bloc  (None, 32, 32, 96)           0         ['convnext_tiny_stage_0_block_
#  k_2_identity (Activation)                                          2_layer_scale[0][0]']
#
#  tf.__operators__.add_2 (TF  (None, 32, 32, 96)           0         ['tf.__operators__.add_1[0][0]
#  OpLambda)                                                          ',
#                                                                      'convnext_tiny_stage_0_block_
#                                                                     2_identity[0][0]']
#
#  convnext_tiny_downsampling  (None, 16, 16, 192)          74112     ['tf.__operators__.add_2[0][0]
#  _block_0 (Sequential)                                              ']
#
#  convnext_tiny_stage_1_bloc  (None, 16, 16, 192)          9600      ['convnext_tiny_downsampling_b
#  k_0_depthwise_conv (Conv2D                                         lock_0[0][0]']
#  )
#
#  convnext_tiny_stage_1_bloc  (None, 16, 16, 192)          384       ['convnext_tiny_stage_1_block_
#  k_0_layernorm (LayerNormal                                         0_depthwise_conv[0][0]']
#  ization)
#
#  convnext_tiny_stage_1_bloc  (None, 16, 16, 768)          148224    ['convnext_tiny_stage_1_block_
#  k_0_pointwise_conv_1 (Dens                                         0_layernorm[0][0]']
#  e)
#
#  convnext_tiny_stage_1_bloc  (None, 16, 16, 768)          0         ['convnext_tiny_stage_1_block_
#  k_0_gelu (Activation)                                              0_pointwise_conv_1[0][0]']
#
#  convnext_tiny_stage_1_bloc  (None, 16, 16, 192)          147648    ['convnext_tiny_stage_1_block_
#  k_0_pointwise_conv_2 (Dens                                         0_gelu[0][0]']
#  e)
#
#  convnext_tiny_stage_1_bloc  (None, 16, 16, 192)          192       ['convnext_tiny_stage_1_block_
#  k_0_layer_scale (LayerScal                                         0_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_tiny_stage_1_bloc  (None, 16, 16, 192)          0         ['convnext_tiny_stage_1_block_
#  k_0_identity (Activation)                                          0_layer_scale[0][0]']
#
#  tf.__operators__.add_3 (TF  (None, 16, 16, 192)          0         ['convnext_tiny_downsampling_b
#  OpLambda)                                                          lock_0[0][0]',
#                                                                      'convnext_tiny_stage_1_block_
#                                                                     0_identity[0][0]']
#
#  convnext_tiny_stage_1_bloc  (None, 16, 16, 192)          9600      ['tf.__operators__.add_3[0][0]
#  k_1_depthwise_conv (Conv2D                                         ']
#  )
#
#  convnext_tiny_stage_1_bloc  (None, 16, 16, 192)          384       ['convnext_tiny_stage_1_block_
#  k_1_layernorm (LayerNormal                                         1_depthwise_conv[0][0]']
#  ization)
#
#  convnext_tiny_stage_1_bloc  (None, 16, 16, 768)          148224    ['convnext_tiny_stage_1_block_
#  k_1_pointwise_conv_1 (Dens                                         1_layernorm[0][0]']
#  e)
#
#  convnext_tiny_stage_1_bloc  (None, 16, 16, 768)          0         ['convnext_tiny_stage_1_block_
#  k_1_gelu (Activation)                                              1_pointwise_conv_1[0][0]']
#
#  convnext_tiny_stage_1_bloc  (None, 16, 16, 192)          147648    ['convnext_tiny_stage_1_block_
#  k_1_pointwise_conv_2 (Dens                                         1_gelu[0][0]']
#  e)
#
#  convnext_tiny_stage_1_bloc  (None, 16, 16, 192)          192       ['convnext_tiny_stage_1_block_
#  k_1_layer_scale (LayerScal                                         1_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_tiny_stage_1_bloc  (None, 16, 16, 192)          0         ['convnext_tiny_stage_1_block_
#  k_1_identity (Activation)                                          1_layer_scale[0][0]']
#
#  tf.__operators__.add_4 (TF  (None, 16, 16, 192)          0         ['tf.__operators__.add_3[0][0]
#  OpLambda)                                                          ',
#                                                                      'convnext_tiny_stage_1_block_
#                                                                     1_identity[0][0]']
#
#  convnext_tiny_stage_1_bloc  (None, 16, 16, 192)          9600      ['tf.__operators__.add_4[0][0]
#  k_2_depthwise_conv (Conv2D                                         ']
#  )
#
#  convnext_tiny_stage_1_bloc  (None, 16, 16, 192)          384       ['convnext_tiny_stage_1_block_
#  k_2_layernorm (LayerNormal                                         2_depthwise_conv[0][0]']
#  ization)
#
#  convnext_tiny_stage_1_bloc  (None, 16, 16, 768)          148224    ['convnext_tiny_stage_1_block_
#  k_2_pointwise_conv_1 (Dens                                         2_layernorm[0][0]']
#  e)
#
#  convnext_tiny_stage_1_bloc  (None, 16, 16, 768)          0         ['convnext_tiny_stage_1_block_
#  k_2_gelu (Activation)                                              2_pointwise_conv_1[0][0]']
#
#  convnext_tiny_stage_1_bloc  (None, 16, 16, 192)          147648    ['convnext_tiny_stage_1_block_
#  k_2_pointwise_conv_2 (Dens                                         2_gelu[0][0]']
#  e)
#
#  convnext_tiny_stage_1_bloc  (None, 16, 16, 192)          192       ['convnext_tiny_stage_1_block_
#  k_2_layer_scale (LayerScal                                         2_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_tiny_stage_1_bloc  (None, 16, 16, 192)          0         ['convnext_tiny_stage_1_block_
#  k_2_identity (Activation)                                          2_layer_scale[0][0]']
#
#  tf.__operators__.add_5 (TF  (None, 16, 16, 192)          0         ['tf.__operators__.add_4[0][0]
#  OpLambda)                                                          ',
#                                                                      'convnext_tiny_stage_1_block_
#                                                                     2_identity[0][0]']
#
#  convnext_tiny_downsampling  (None, 8, 8, 384)            295680    ['tf.__operators__.add_5[0][0]
#  _block_1 (Sequential)                                              ']
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 384)            19200     ['convnext_tiny_downsampling_b
#  k_0_depthwise_conv (Conv2D                                         lock_1[0][0]']
#  )
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 384)            768       ['convnext_tiny_stage_2_block_
#  k_0_layernorm (LayerNormal                                         0_depthwise_conv[0][0]']
#  ization)
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 1536)           591360    ['convnext_tiny_stage_2_block_
#  k_0_pointwise_conv_1 (Dens                                         0_layernorm[0][0]']
#  e)
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 1536)           0         ['convnext_tiny_stage_2_block_
#  k_0_gelu (Activation)                                              0_pointwise_conv_1[0][0]']
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 384)            590208    ['convnext_tiny_stage_2_block_
#  k_0_pointwise_conv_2 (Dens                                         0_gelu[0][0]']
#  e)
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 384)            384       ['convnext_tiny_stage_2_block_
#  k_0_layer_scale (LayerScal                                         0_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 384)            0         ['convnext_tiny_stage_2_block_
#  k_0_identity (Activation)                                          0_layer_scale[0][0]']
#
#  tf.__operators__.add_6 (TF  (None, 8, 8, 384)            0         ['convnext_tiny_downsampling_b
#  OpLambda)                                                          lock_1[0][0]',
#                                                                      'convnext_tiny_stage_2_block_
#                                                                     0_identity[0][0]']
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 384)            19200     ['tf.__operators__.add_6[0][0]
#  k_1_depthwise_conv (Conv2D                                         ']
#  )
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 384)            768       ['convnext_tiny_stage_2_block_
#  k_1_layernorm (LayerNormal                                         1_depthwise_conv[0][0]']
#  ization)
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 1536)           591360    ['convnext_tiny_stage_2_block_
#  k_1_pointwise_conv_1 (Dens                                         1_layernorm[0][0]']
#  e)
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 1536)           0         ['convnext_tiny_stage_2_block_
#  k_1_gelu (Activation)                                              1_pointwise_conv_1[0][0]']
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 384)            590208    ['convnext_tiny_stage_2_block_
#  k_1_pointwise_conv_2 (Dens                                         1_gelu[0][0]']
#  e)
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 384)            384       ['convnext_tiny_stage_2_block_
#  k_1_layer_scale (LayerScal                                         1_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 384)            0         ['convnext_tiny_stage_2_block_
#  k_1_identity (Activation)                                          1_layer_scale[0][0]']
#
#  tf.__operators__.add_7 (TF  (None, 8, 8, 384)            0         ['tf.__operators__.add_6[0][0]
#  OpLambda)                                                          ',
#                                                                      'convnext_tiny_stage_2_block_
#                                                                     1_identity[0][0]']
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 384)            19200     ['tf.__operators__.add_7[0][0]
#  k_2_depthwise_conv (Conv2D                                         ']
#  )
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 384)            768       ['convnext_tiny_stage_2_block_
#  k_2_layernorm (LayerNormal                                         2_depthwise_conv[0][0]']
#  ization)
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 1536)           591360    ['convnext_tiny_stage_2_block_
#  k_2_pointwise_conv_1 (Dens                                         2_layernorm[0][0]']
#  e)
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 1536)           0         ['convnext_tiny_stage_2_block_
#  k_2_gelu (Activation)                                              2_pointwise_conv_1[0][0]']
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 384)            590208    ['convnext_tiny_stage_2_block_
#  k_2_pointwise_conv_2 (Dens                                         2_gelu[0][0]']
#  e)
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 384)            384       ['convnext_tiny_stage_2_block_
#  k_2_layer_scale (LayerScal                                         2_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 384)            0         ['convnext_tiny_stage_2_block_
#  k_2_identity (Activation)                                          2_layer_scale[0][0]']
#
#  tf.__operators__.add_8 (TF  (None, 8, 8, 384)            0         ['tf.__operators__.add_7[0][0]
#  OpLambda)                                                          ',
#                                                                      'convnext_tiny_stage_2_block_
#                                                                     2_identity[0][0]']
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 384)            19200     ['tf.__operators__.add_8[0][0]
#  k_3_depthwise_conv (Conv2D                                         ']
#  )
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 384)            768       ['convnext_tiny_stage_2_block_
#  k_3_layernorm (LayerNormal                                         3_depthwise_conv[0][0]']
#  ization)
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 1536)           591360    ['convnext_tiny_stage_2_block_
#  k_3_pointwise_conv_1 (Dens                                         3_layernorm[0][0]']
#  e)
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 1536)           0         ['convnext_tiny_stage_2_block_
#  k_3_gelu (Activation)                                              3_pointwise_conv_1[0][0]']
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 384)            590208    ['convnext_tiny_stage_2_block_
#  k_3_pointwise_conv_2 (Dens                                         3_gelu[0][0]']
#  e)
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 384)            384       ['convnext_tiny_stage_2_block_
#  k_3_layer_scale (LayerScal                                         3_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 384)            0         ['convnext_tiny_stage_2_block_
#  k_3_identity (Activation)                                          3_layer_scale[0][0]']
#
#  tf.__operators__.add_9 (TF  (None, 8, 8, 384)            0         ['tf.__operators__.add_8[0][0]
#  OpLambda)                                                          ',
#                                                                      'convnext_tiny_stage_2_block_
#                                                                     3_identity[0][0]']
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 384)            19200     ['tf.__operators__.add_9[0][0]
#  k_4_depthwise_conv (Conv2D                                         ']
#  )
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 384)            768       ['convnext_tiny_stage_2_block_
#  k_4_layernorm (LayerNormal                                         4_depthwise_conv[0][0]']
#  ization)
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 1536)           591360    ['convnext_tiny_stage_2_block_
#  k_4_pointwise_conv_1 (Dens                                         4_layernorm[0][0]']
#  e)
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 1536)           0         ['convnext_tiny_stage_2_block_
#  k_4_gelu (Activation)                                              4_pointwise_conv_1[0][0]']
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 384)            590208    ['convnext_tiny_stage_2_block_
#  k_4_pointwise_conv_2 (Dens                                         4_gelu[0][0]']
#  e)
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 384)            384       ['convnext_tiny_stage_2_block_
#  k_4_layer_scale (LayerScal                                         4_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 384)            0         ['convnext_tiny_stage_2_block_
#  k_4_identity (Activation)                                          4_layer_scale[0][0]']
#
#  tf.__operators__.add_10 (T  (None, 8, 8, 384)            0         ['tf.__operators__.add_9[0][0]
#  FOpLambda)                                                         ',
#                                                                      'convnext_tiny_stage_2_block_
#                                                                     4_identity[0][0]']
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 384)            19200     ['tf.__operators__.add_10[0][0
#  k_5_depthwise_conv (Conv2D                                         ]']
#  )
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 384)            768       ['convnext_tiny_stage_2_block_
#  k_5_layernorm (LayerNormal                                         5_depthwise_conv[0][0]']
#  ization)
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 1536)           591360    ['convnext_tiny_stage_2_block_
#  k_5_pointwise_conv_1 (Dens                                         5_layernorm[0][0]']
#  e)
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 1536)           0         ['convnext_tiny_stage_2_block_
#  k_5_gelu (Activation)                                              5_pointwise_conv_1[0][0]']
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 384)            590208    ['convnext_tiny_stage_2_block_
#  k_5_pointwise_conv_2 (Dens                                         5_gelu[0][0]']
#  e)
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 384)            384       ['convnext_tiny_stage_2_block_
#  k_5_layer_scale (LayerScal                                         5_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 384)            0         ['convnext_tiny_stage_2_block_
#  k_5_identity (Activation)                                          5_layer_scale[0][0]']
#
#  tf.__operators__.add_11 (T  (None, 8, 8, 384)            0         ['tf.__operators__.add_10[0][0
#  FOpLambda)                                                         ]',
#                                                                      'convnext_tiny_stage_2_block_
#                                                                     5_identity[0][0]']
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 384)            19200     ['tf.__operators__.add_11[0][0
#  k_6_depthwise_conv (Conv2D                                         ]']
#  )
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 384)            768       ['convnext_tiny_stage_2_block_
#  k_6_layernorm (LayerNormal                                         6_depthwise_conv[0][0]']
#  ization)
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 1536)           591360    ['convnext_tiny_stage_2_block_
#  k_6_pointwise_conv_1 (Dens                                         6_layernorm[0][0]']
#  e)
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 1536)           0         ['convnext_tiny_stage_2_block_
#  k_6_gelu (Activation)                                              6_pointwise_conv_1[0][0]']
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 384)            590208    ['convnext_tiny_stage_2_block_
#  k_6_pointwise_conv_2 (Dens                                         6_gelu[0][0]']
#  e)
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 384)            384       ['convnext_tiny_stage_2_block_
#  k_6_layer_scale (LayerScal                                         6_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 384)            0         ['convnext_tiny_stage_2_block_
#  k_6_identity (Activation)                                          6_layer_scale[0][0]']
#
#  tf.__operators__.add_12 (T  (None, 8, 8, 384)            0         ['tf.__operators__.add_11[0][0
#  FOpLambda)                                                         ]',
#                                                                      'convnext_tiny_stage_2_block_
#                                                                     6_identity[0][0]']
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 384)            19200     ['tf.__operators__.add_12[0][0
#  k_7_depthwise_conv (Conv2D                                         ]']
#  )
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 384)            768       ['convnext_tiny_stage_2_block_
#  k_7_layernorm (LayerNormal                                         7_depthwise_conv[0][0]']
#  ization)
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 1536)           591360    ['convnext_tiny_stage_2_block_
#  k_7_pointwise_conv_1 (Dens                                         7_layernorm[0][0]']
#  e)
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 1536)           0         ['convnext_tiny_stage_2_block_
#  k_7_gelu (Activation)                                              7_pointwise_conv_1[0][0]']
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 384)            590208    ['convnext_tiny_stage_2_block_
#  k_7_pointwise_conv_2 (Dens                                         7_gelu[0][0]']
#  e)
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 384)            384       ['convnext_tiny_stage_2_block_
#  k_7_layer_scale (LayerScal                                         7_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 384)            0         ['convnext_tiny_stage_2_block_
#  k_7_identity (Activation)                                          7_layer_scale[0][0]']
#
#  tf.__operators__.add_13 (T  (None, 8, 8, 384)            0         ['tf.__operators__.add_12[0][0
#  FOpLambda)                                                         ]',
#                                                                      'convnext_tiny_stage_2_block_
#                                                                     7_identity[0][0]']
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 384)            19200     ['tf.__operators__.add_13[0][0
#  k_8_depthwise_conv (Conv2D                                         ]']
#  )
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 384)            768       ['convnext_tiny_stage_2_block_
#  k_8_layernorm (LayerNormal                                         8_depthwise_conv[0][0]']
#  ization)
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 1536)           591360    ['convnext_tiny_stage_2_block_
#  k_8_pointwise_conv_1 (Dens                                         8_layernorm[0][0]']
#  e)
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 1536)           0         ['convnext_tiny_stage_2_block_
#  k_8_gelu (Activation)                                              8_pointwise_conv_1[0][0]']
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 384)            590208    ['convnext_tiny_stage_2_block_
#  k_8_pointwise_conv_2 (Dens                                         8_gelu[0][0]']
#  e)
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 384)            384       ['convnext_tiny_stage_2_block_
#  k_8_layer_scale (LayerScal                                         8_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_tiny_stage_2_bloc  (None, 8, 8, 384)            0         ['convnext_tiny_stage_2_block_
#  k_8_identity (Activation)                                          8_layer_scale[0][0]']
#
#  tf.__operators__.add_14 (T  (None, 8, 8, 384)            0         ['tf.__operators__.add_13[0][0
#  FOpLambda)                                                         ]',
#                                                                      'convnext_tiny_stage_2_block_
#                                                                     8_identity[0][0]']
#
#  convnext_tiny_downsampling  (None, 4, 4, 768)            1181184   ['tf.__operators__.add_14[0][0
#  _block_2 (Sequential)                                              ]']
#
#  convnext_tiny_stage_3_bloc  (None, 4, 4, 768)            38400     ['convnext_tiny_downsampling_b
#  k_0_depthwise_conv (Conv2D                                         lock_2[0][0]']
#  )
#
#  convnext_tiny_stage_3_bloc  (None, 4, 4, 768)            1536      ['convnext_tiny_stage_3_block_
#  k_0_layernorm (LayerNormal                                         0_depthwise_conv[0][0]']
#  ization)
#
#  convnext_tiny_stage_3_bloc  (None, 4, 4, 3072)           2362368   ['convnext_tiny_stage_3_block_
#  k_0_pointwise_conv_1 (Dens                                         0_layernorm[0][0]']
#  e)
#
#  convnext_tiny_stage_3_bloc  (None, 4, 4, 3072)           0         ['convnext_tiny_stage_3_block_
#  k_0_gelu (Activation)                                              0_pointwise_conv_1[0][0]']
#
#  convnext_tiny_stage_3_bloc  (None, 4, 4, 768)            2360064   ['convnext_tiny_stage_3_block_
#  k_0_pointwise_conv_2 (Dens                                         0_gelu[0][0]']
#  e)
#
#  convnext_tiny_stage_3_bloc  (None, 4, 4, 768)            768       ['convnext_tiny_stage_3_block_
#  k_0_layer_scale (LayerScal                                         0_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_tiny_stage_3_bloc  (None, 4, 4, 768)            0         ['convnext_tiny_stage_3_block_
#  k_0_identity (Activation)                                          0_layer_scale[0][0]']
#
#  tf.__operators__.add_15 (T  (None, 4, 4, 768)            0         ['convnext_tiny_downsampling_b
#  FOpLambda)                                                         lock_2[0][0]',
#                                                                      'convnext_tiny_stage_3_block_
#                                                                     0_identity[0][0]']
#
#  convnext_tiny_stage_3_bloc  (None, 4, 4, 768)            38400     ['tf.__operators__.add_15[0][0
#  k_1_depthwise_conv (Conv2D                                         ]']
#  )
#
#  convnext_tiny_stage_3_bloc  (None, 4, 4, 768)            1536      ['convnext_tiny_stage_3_block_
#  k_1_layernorm (LayerNormal                                         1_depthwise_conv[0][0]']
#  ization)
#
#  convnext_tiny_stage_3_bloc  (None, 4, 4, 3072)           2362368   ['convnext_tiny_stage_3_block_
#  k_1_pointwise_conv_1 (Dens                                         1_layernorm[0][0]']
#  e)
#
#  convnext_tiny_stage_3_bloc  (None, 4, 4, 3072)           0         ['convnext_tiny_stage_3_block_
#  k_1_gelu (Activation)                                              1_pointwise_conv_1[0][0]']
#
#  convnext_tiny_stage_3_bloc  (None, 4, 4, 768)            2360064   ['convnext_tiny_stage_3_block_
#  k_1_pointwise_conv_2 (Dens                                         1_gelu[0][0]']
#  e)
#
#  convnext_tiny_stage_3_bloc  (None, 4, 4, 768)            768       ['convnext_tiny_stage_3_block_
#  k_1_layer_scale (LayerScal                                         1_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_tiny_stage_3_bloc  (None, 4, 4, 768)            0         ['convnext_tiny_stage_3_block_
#  k_1_identity (Activation)                                          1_layer_scale[0][0]']
#
#  tf.__operators__.add_16 (T  (None, 4, 4, 768)            0         ['tf.__operators__.add_15[0][0
#  FOpLambda)                                                         ]',
#                                                                      'convnext_tiny_stage_3_block_
#                                                                     1_identity[0][0]']
#
#  convnext_tiny_stage_3_bloc  (None, 4, 4, 768)            38400     ['tf.__operators__.add_16[0][0
#  k_2_depthwise_conv (Conv2D                                         ]']
#  )
#
#  convnext_tiny_stage_3_bloc  (None, 4, 4, 768)            1536      ['convnext_tiny_stage_3_block_
#  k_2_layernorm (LayerNormal                                         2_depthwise_conv[0][0]']
#  ization)
#
#  convnext_tiny_stage_3_bloc  (None, 4, 4, 3072)           2362368   ['convnext_tiny_stage_3_block_
#  k_2_pointwise_conv_1 (Dens                                         2_layernorm[0][0]']
#  e)
#
#  convnext_tiny_stage_3_bloc  (None, 4, 4, 3072)           0         ['convnext_tiny_stage_3_block_
#  k_2_gelu (Activation)                                              2_pointwise_conv_1[0][0]']
#
#  convnext_tiny_stage_3_bloc  (None, 4, 4, 768)            2360064   ['convnext_tiny_stage_3_block_
#  k_2_pointwise_conv_2 (Dens                                         2_gelu[0][0]']
#  e)
#
#  convnext_tiny_stage_3_bloc  (None, 4, 4, 768)            768       ['convnext_tiny_stage_3_block_
#  k_2_layer_scale (LayerScal                                         2_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_tiny_stage_3_bloc  (None, 4, 4, 768)            0         ['convnext_tiny_stage_3_block_
#  k_2_identity (Activation)                                          2_layer_scale[0][0]']
#
#  tf.__operators__.add_17 (T  (None, 4, 4, 768)            0         ['tf.__operators__.add_16[0][0
#  FOpLambda)                                                         ]',
#                                                                      'convnext_tiny_stage_3_block_
#                                                                     2_identity[0][0]']
#
#  layer_normalization (Layer  (None, 4, 4, 768)            1536      ['tf.__operators__.add_17[0][0
#  Normalization)                                                     ]']
#
#  global_average_pooling2d (  (None, 768)                  0         ['layer_normalization[0][0]']
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 125)                  96125     ['global_average_pooling2d[0][
#                                                                     0]']
#
#  dense_1 (Dense)             (None, 5)                    630       ['dense[0][0]']
#
# ==================================================================================================
# Total params: 27916883 (106.49 MB)
# Trainable params: 27916883 (106.49 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
classification_model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Define callbacks
checkpoint = ModelCheckpoint("/content/drive/MyDrive/N/convnext.h5", monitor='val_loss', verbose=1, save_best_only=True, mode='min')
early_stopping = EarlyStopping(monitor='val_loss', patience=7, verbose=1, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=1e-6, verbose=1)

# Train the model
history = classification_model.fit(x_train, y_train, epochs=25, batch_size=32, validation_data=(x_test, y_test), callbacks=[checkpoint, early_stopping, reduce_lr])
# Out:
# Epoch 1/25
# 69/69 [==============================] - ETA: 0s - loss: 1.4102 - accuracy: 0.3977
# Epoch 1: val_loss improved from inf to 1.01626, saving model to /content/drive/MyDrive/N/convnext.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 69/69 [==============================] - 81s 547ms/step - loss: 1.4102 - accuracy: 0.3977 - val_loss: 1.0163 - val_accuracy: 0.5836 - lr: 0.0010
# Epoch 2/25
# 69/69 [==============================] - ETA: 0s - loss: 1.0492 - accuracy: 0.5495
# Epoch 2: val_loss improved from 1.01626 to 0.93652, saving model to /content/drive/MyDrive/N/convnext.h5
# 69/69 [==============================] - 20s 292ms/step - loss: 1.0492 - accuracy: 0.5495 - val_loss: 0.9365 - val_accuracy: 0.5891 - lr: 0.0010
# Epoch 3/25
# 69/69 [==============================] - ETA: 0s - loss: 0.9004 - accuracy: 0.6086
# Epoch 3: val_loss improved from 0.93652 to 0.78608, saving model to /content/drive/MyDrive/N/convnext.h5
# 69/69 [==============================] - 19s 281ms/step - loss: 0.9004 - accuracy: 0.6086 - val_loss: 0.7861 - val_accuracy: 0.6636 - lr: 0.0010
# Epoch 4/25
# 69/69 [==============================] - ETA: 0s - loss: 0.6971 - accuracy: 0.7177
# Epoch 4: val_loss improved from 0.78608 to 0.70065, saving model to /content/drive/MyDrive/N/convnext.h5
# 69/69 [==============================] - 21s 298ms/step - loss: 0.6971 - accuracy: 0.7177 - val_loss: 0.7006 - val_accuracy: 0.7000 - lr: 0.0010
# Epoch 5/25
# 69/69 [==============================] - ETA: 0s - loss: 0.5298 - accuracy: 0.7936
# Epoch 5: val_loss did not improve from 0.70065
# 69/69 [==============================] - 19s 272ms/step - loss: 0.5298 - accuracy: 0.7936 - val_loss: 0.7501 - val_accuracy: 0.6927 - lr: 0.0010
# Epoch 6/25
# 69/69 [==============================] - ETA: 0s - loss: 0.5034 - accuracy: 0.7950
# Epoch 6: val_loss did not improve from 0.70065
# 69/69 [==============================] - 19s 272ms/step - loss: 0.5034 - accuracy: 0.7950 - val_loss: 1.0444 - val_accuracy: 0.6018 - lr: 0.0010
# Epoch 7/25
# 69/69 [==============================] - ETA: 0s - loss: 0.3856 - accuracy: 0.8600
# Epoch 7: val_loss did not improve from 0.70065
# 69/69 [==============================] - 18s 268ms/step - loss: 0.3856 - accuracy: 0.8600 - val_loss: 0.7397 - val_accuracy: 0.7255 - lr: 0.0010
# Epoch 8/25
# 69/69 [==============================] - ETA: 0s - loss: 0.2593 - accuracy: 0.9050
# Epoch 8: val_loss did not improve from 0.70065
# 69/69 [==============================] - 18s 268ms/step - loss: 0.2593 - accuracy: 0.9050 - val_loss: 1.0201 - val_accuracy: 0.6200 - lr: 0.0010
# Epoch 9/25
# 69/69 [==============================] - ETA: 0s - loss: 0.3037 - accuracy: 0.8955
# Epoch 9: val_loss did not improve from 0.70065
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 69/69 [==============================] - 19s 269ms/step - loss: 0.3037 - accuracy: 0.8955 - val_loss: 0.8511 - val_accuracy: 0.6927 - lr: 0.0010
# Epoch 10/25
# 69/69 [==============================] - ETA: 0s - loss: 0.1173 - accuracy: 0.9659
# Epoch 10: val_loss improved from 0.70065 to 0.61843, saving model to /content/drive/MyDrive/N/convnext.h5
# 69/69 [==============================] - 27s 392ms/step - loss: 0.1173 - accuracy: 0.9659 - val_loss: 0.6184 - val_accuracy: 0.7782 - lr: 2.0000e-04
# Epoch 11/25
# 69/69 [==============================] - ETA: 0s - loss: 0.0300 - accuracy: 0.9995
# Epoch 11: val_loss improved from 0.61843 to 0.60910, saving model to /content/drive/MyDrive/N/convnext.h5
# 69/69 [==============================] - 20s 283ms/step - loss: 0.0300 - accuracy: 0.9995 - val_loss: 0.6091 - val_accuracy: 0.7800 - lr: 2.0000e-04
# Epoch 12/25
# 69/69 [==============================] - ETA: 0s - loss: 0.0172 - accuracy: 1.0000
# Epoch 12: val_loss did not improve from 0.60910
# 69/69 [==============================] - 19s 272ms/step - loss: 0.0172 - accuracy: 1.0000 - val_loss: 0.6274 - val_accuracy: 0.7764 - lr: 2.0000e-04
# Epoch 13/25
# 69/69 [==============================] - ETA: 0s - loss: 0.0119 - accuracy: 1.0000
# Epoch 13: val_loss did not improve from 0.60910
# 69/69 [==============================] - 19s 271ms/step - loss: 0.0119 - accuracy: 1.0000 - val_loss: 0.6638 - val_accuracy: 0.7927 - lr: 2.0000e-04
# Epoch 14/25
# 69/69 [==============================] - ETA: 0s - loss: 0.0089 - accuracy: 1.0000
# Epoch 14: val_loss did not improve from 0.60910
# 69/69 [==============================] - 17s 252ms/step - loss: 0.0089 - accuracy: 1.0000 - val_loss: 0.6967 - val_accuracy: 0.7891 - lr: 2.0000e-04
# Epoch 15/25
# 69/69 [==============================] - ETA: 0s - loss: 0.0071 - accuracy: 1.0000
# Epoch 15: val_loss did not improve from 0.60910
# 69/69 [==============================] - 19s 270ms/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 0.7284 - val_accuracy: 0.7891 - lr: 2.0000e-04
# Epoch 16/25
# 69/69 [==============================] - ETA: 0s - loss: 0.0058 - accuracy: 1.0000
# Epoch 16: val_loss did not improve from 0.60910
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 69/69 [==============================] - 17s 252ms/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.7525 - val_accuracy: 0.7927 - lr: 2.0000e-04
# Epoch 17/25
# 69/69 [==============================] - ETA: 0s - loss: 0.0051 - accuracy: 1.0000
# Epoch 17: val_loss did not improve from 0.60910
# 69/69 [==============================] - 19s 269ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.7592 - val_accuracy: 0.7927 - lr: 4.0000e-05
# Epoch 18/25
# 69/69 [==============================] - ETA: 0s - loss: 0.0049 - accuracy: 1.0000
# Epoch 18: val_loss did not improve from 0.60910
# Restoring model weights from the end of the best epoch: 11.
# 69/69 [==============================] - 18s 256ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.7652 - val_accuracy: 0.7927 - lr: 4.0000e-05
# Epoch 18: early stopping

# %%
classification_model.load_weights("/content/drive/MyDrive/N/convnext.h5")
classification_model.evaluate(x_test, y_test)
# Out:
# 18/18 [==============================] - 2s 83ms/step - loss: 0.6091 - accuracy: 0.7800
# [0.6090954542160034, 0.7799999713897705]

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

# Assuming classification_model.predict returns probabilities or predicted classes
y_pred = classification_model.predict(x_test)

# If y_pred contains probabilities, you may want to convert them to classes
# For binary classification:
# y_pred_classes = (y_pred > 0.5).astype(int)

# For multi-class classification with softmax output:
y_pred_classes = np.argmax(y_pred, axis=1)
from sklearn.metrics import classification_report

# Assuming y_pred_classes are predicted classes

# Generate classification report
report = classification_report(y_test, y_pred_classes, digits=5)

# Print the report
print("Classification Report:")
print(report)
# Out:
# 18/18 [==============================] - 3s 82ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0    0.88776   0.79817   0.84058       109
#            1    0.93578   0.87179   0.90265       117
#            2    0.83019   0.85437   0.84211       103
#            3    0.64865   0.63717   0.64286       113
#            4    0.63492   0.74074   0.68376       108
#
#     accuracy                        0.78000       550
#    macro avg    0.78746   0.78045   0.78239       550
# weighted avg    0.78842   0.78000   0.78265       550

# %%
# Visualize t-SNE embeddings
# Assuming x_train_embed and x_test_embed are the embeddings obtained from the penultimate layer
tsne = TSNE(n_components=2, random_state=42)
x_embed = base_model.predict(x_test)  # Assuming x_test is your test data
x_tsne = tsne.fit_transform(x_embed)

# Plot t-SNE embeddings
plt.figure(figsize=(10, 8))
plt.scatter(x_tsne[:, 0], x_tsne[:, 1], c=y_test, cmap='viridis')
plt.colorbar()
plt.title(' Test t-SNE Embeddings')
plt.xlabel('t-SNE Component 1')
plt.ylabel('t-SNE Component 2')
plt.show()
# Out:
# 18/18 [==============================] - 3s 80ms/step

# %%
# Visualize t-SNE embeddings
# Assuming x_train_embed and x_test_embed are the embeddings obtained from the penultimate layer
x_test_flat = x_test.reshape((550, 128*128*3))
tsne = TSNE(n_components=2, random_state=42)
#x_embed = base_model.predict(x_test)  # Assuming x_test is your test data
x_tsne = tsne.fit_transform(x_test_flat)

# Plot t-SNE embeddings
plt.figure(figsize=(10, 8))
plt.scatter(x_tsne[:, 0], x_tsne[:, 1], c=y_test, cmap='viridis')
plt.colorbar()
plt.title(' Test Images')
plt.xlabel('t-SNE Component 1')
plt.ylabel('t-SNE Component 2')
plt.show()

# %%
# Visualize t-SNE embeddings
# Assuming x_train_embed and x_train_embed are the embeddings obtained from the penultimate layer
x_train_flat = x_train.reshape((2200, 128*128*3))
tsne = TSNE(n_components=2, random_state=42)
#x_embed = base_model.predict(x_train)  # Assuming x_train is your train data
x_tsne = tsne.fit_transform(x_train_flat)

# Plot t-SNE embeddings
plt.figure(figsize=(10, 8))
plt.scatter(x_tsne[:, 0], x_tsne[:, 1], c=y_train, cmap='viridis')
plt.colorbar()
plt.title('Train Images')
plt.xlabel('t-SNE Component 1')
plt.ylabel('t-SNE Component 2')
plt.show()

# %%
# Visualize t-SNE embeddings
# Assuming x_train_embed and x_train_embed are the embeddings obtained from the penultimate layer
tsne = TSNE(n_components=2, random_state=42)
x_embed = base_model.predict(x_train)  # Assuming x_train is your train data
x_tsne = tsne.fit_transform(x_embed)

# Plot t-SNE embeddings
plt.figure(figsize=(10, 8))
plt.scatter(x_tsne[:, 0], x_tsne[:, 1], c=y_train, cmap='viridis')
plt.colorbar()
plt.title('Train t-SNE Embeddings')
plt.xlabel('t-SNE Component 1')
plt.ylabel('t-SNE Component 2')
plt.show()
# Out:
# 69/69 [==============================] - 7s 101ms/step

# %% [markdown]
# <h1>E-Mixup

# %%
xtest_emb = base_model.predict(x_test)
xtrain_emb = base_model.predict(x_train)
# Out:
# 18/18 [==============================] - 2s 82ms/step
# 69/69 [==============================] - 6s 84ms/step

# %%
import keras
y_test_o = keras.utils.to_categorical(y_test)
y_train_o = keras.utils.to_categorical(y_train)
print(y_train_o.shape)
print(y_test_o.shape)
# Out:
# (2200, 5)
# (550, 5)

# %%
def mixup(xt, yt, mf):
  alp = 0.2
  xaug = []
  yaug = []
  for k in range(0,xt.shape[0]):
    cnt = 0
    for cnt in range(0,mf-1):
      lbd = np.random.beta(alp,alp)
      yks = np.random.randint(xt.shape[0])
      kdash = xt[yks]
      ydash = yt[yks]
      kdash1 = xt[k]
      ydash1 = yt[k]
      xaug1 = kdash1*lbd + kdash*(1-lbd)
      yaug1 = ydash1*lbd + ydash*(1-lbd)
      xaug.append(xaug1)
      yaug.append(yaug1)
  xs2 = np.asarray(xaug)
  ys2 = np.asarray(yaug)
  x1 = np.concatenate((xt,xs2))
  y1 = np.concatenate((yt,ys2))
  return x1,y1

# %%
xtrain_emb.shape
# Out:
# (2200, 125)

# %%
xtt, ytt = mixup(xtrain_emb,y_train_o,3)
xtt.shape
# Out:
# (6600, 125)

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
import tensorflow as tf

Classifier_model = Sequential()
#add model layers
Classifier_model.Input = (125,)

Classifier_model.add(Dense(512,activation='relu'))
Classifier_model.add(Dense(512,activation='relu'))

Classifier_model.add(Dense(5, activation='softmax'))
opt = tf.keras.optimizers.Adam(learning_rate=0.001)
Classifier_model.compile(optimizer=opt,loss='categorical_crossentropy',metrics=['accuracy'])
Classifier_model.fit(xtt, ytt,epochs=25, validation_data=(xtest_emb, y_test_o))
# Out:
# Epoch 1/25
# 207/207 [==============================] - 2s 4ms/step - loss: 0.1977 - accuracy: 0.9856 - val_loss: 0.6608 - val_accuracy: 0.7873
# Epoch 2/25
# 207/207 [==============================] - 1s 3ms/step - loss: 0.1602 - accuracy: 0.9885 - val_loss: 0.7105 - val_accuracy: 0.7891
# Epoch 3/25
# 207/207 [==============================] - 1s 3ms/step - loss: 0.1506 - accuracy: 0.9865 - val_loss: 0.6748 - val_accuracy: 0.7927
# Epoch 4/25
# 207/207 [==============================] - 1s 3ms/step - loss: 0.1452 - accuracy: 0.9898 - val_loss: 0.7058 - val_accuracy: 0.7945
# Epoch 5/25
# 207/207 [==============================] - 1s 3ms/step - loss: 0.1408 - accuracy: 0.9905 - val_loss: 0.7554 - val_accuracy: 0.7873
# Epoch 6/25
# 207/207 [==============================] - 1s 5ms/step - loss: 0.1400 - accuracy: 0.9877 - val_loss: 0.7169 - val_accuracy: 0.7855
# Epoch 7/25
# 207/207 [==============================] - 1s 5ms/step - loss: 0.1363 - accuracy: 0.9903 - val_loss: 0.8089 - val_accuracy: 0.7745
# Epoch 8/25
# 207/207 [==============================] - 1s 5ms/step - loss: 0.1353 - accuracy: 0.9891 - val_loss: 0.7793 - val_accuracy: 0.7818
# Epoch 9/25
# 207/207 [==============================] - 1s 3ms/step - loss: 0.1343 - accuracy: 0.9895 - val_loss: 0.7904 - val_accuracy: 0.7873
# Epoch 10/25
# 207/207 [==============================] - 1s 3ms/step - loss: 0.1323 - accuracy: 0.9918 - val_loss: 0.8228 - val_accuracy: 0.7709
# Epoch 11/25
# 207/207 [==============================] - 1s 3ms/step - loss: 0.1309 - accuracy: 0.9924 - val_loss: 0.7909 - val_accuracy: 0.7927
# Epoch 12/25
# 207/207 [==============================] - 1s 3ms/step - loss: 0.1308 - accuracy: 0.9909 - val_loss: 0.8683 - val_accuracy: 0.7855
# Epoch 13/25
# 207/207 [==============================] - 1s 3ms/step - loss: 0.1301 - accuracy: 0.9909 - val_loss: 0.8554 - val_accuracy: 0.7855
# Epoch 14/25
# 207/207 [==============================] - 1s 4ms/step - loss: 0.1290 - accuracy: 0.9915 - val_loss: 0.8284 - val_accuracy: 0.7873
# Epoch 15/25
# 207/207 [==============================] - 1s 3ms/step - loss: 0.1288 - accuracy: 0.9914 - val_loss: 0.8714 - val_accuracy: 0.7855
# Epoch 16/25
# 207/207 [==============================] - 1s 3ms/step - loss: 0.1284 - accuracy: 0.9918 - val_loss: 0.9413 - val_accuracy: 0.7836
# Epoch 17/25
# 207/207 [==============================] - 1s 3ms/step - loss: 0.1284 - accuracy: 0.9915 - val_loss: 0.9425 - val_accuracy: 0.7764
# Epoch 18/25
# 207/207 [==============================] - 1s 3ms/step - loss: 0.1273 - accuracy: 0.9935 - val_loss: 0.9257 - val_accuracy: 0.7855
# Epoch 19/25
# 207/207 [==============================] - 1s 4ms/step - loss: 0.1271 - accuracy: 0.9933 - val_loss: 0.9193 - val_accuracy: 0.7782
# Epoch 20/25
# 207/207 [==============================] - 1s 3ms/step - loss: 0.1268 - accuracy: 0.9918 - val_loss: 0.9810 - val_accuracy: 0.7855
# Epoch 21/25
# 207/207 [==============================] - 1s 4ms/step - loss: 0.1261 - accuracy: 0.9923 - val_loss: 1.0833 - val_accuracy: 0.7800
# Epoch 22/25
# 207/207 [==============================] - 1s 4ms/step - loss: 0.1266 - accuracy: 0.9929 - val_loss: 0.9473 - val_accuracy: 0.7800
# Epoch 23/25
# 207/207 [==============================] - 1s 5ms/step - loss: 0.1255 - accuracy: 0.9935 - val_loss: 0.9916 - val_accuracy: 0.7745
# Epoch 24/25
# 207/207 [==============================] - 1s 5ms/step - loss: 0.1256 - accuracy: 0.9939 - val_loss: 1.0410 - val_accuracy: 0.7873
# Epoch 25/25
# 207/207 [==============================] - 1s 5ms/step - loss: 0.1257 - accuracy: 0.9920 - val_loss: 1.0684 - val_accuracy: 0.7855

# %%
Classifier_model.evaluate(xtest_emb, y_test_o)
# Out:
# 18/18 [==============================] - 0s 2ms/step - loss: 1.0684 - accuracy: 0.7855
# [1.0684095621109009, 0.7854545712471008]

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

# Assuming Classifier_model.predict returns probabilities or predicted classes
y_pred = Classifier_model.predict(xtest_emb)

# If y_pred contains probabilities, you may want to convert them to classes
# For binary classification:
# y_pred_classes = (y_pred > 0.5).astype(int)
# For multi-class classification with softmax output:
y_pred_classes = np.argmax(y_pred, axis=1)
from sklearn.metrics import classification_report

# Assuming y_pred_classes are predicted classes

# Generate classification report
report = classification_report(y_test, y_pred_classes, digits=5)

# Print the report
print("Classification Report:")
print(report)
# Out:
# 18/18 [==============================] - 0s 2ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0    0.93333   0.77064   0.84422       109
#            1    0.94175   0.82906   0.88182       117
#            2    0.82407   0.86408   0.84360       103
#            3    0.62406   0.73451   0.67480       113
#            4    0.68103   0.73148   0.70536       108
#
#     accuracy                        0.78545       550
#    macro avg    0.80085   0.78595   0.78996       550
# weighted avg    0.80158   0.78545   0.79003       550

# %% [markdown]
# E-Stitchup

# %%
import numpy as np

def stichup(xt, yt, mf):
    alp = 0.2
    xaug = []
    yaug = []
    for k in range(xt.shape[0]):
        for _ in range(mf-1):  # Renamed loop counter to avoid confusion with loop index
            lbd = np.random.beta(alp, alp)
            yks = np.random.randint(xt.shape[0])
            kdash = xt[yks]  # Accessing rows of xt directly
            ydash = yt[yks]  # Accessing corresponding y value
            kdash1 = xt[k]    # Accessing rows of xt directly
            ydash1 = yt[k]    # Accessing corresponding y value
            lbd_stch = int(xt.shape[1] * lbd)
            reff_stich = np.zeros(xt.shape[1])
            for i in range(lbd_stch):
                index_stich = np.random.randint(xt.shape[1])
                reff_stich[index_stich] = 1
            xaug1 = np.zeros(xt.shape[1])  # Initialize as numpy array
            for i in range(len(reff_stich)):
                if reff_stich[i] == 0:
                    xaug1[i] = kdash[i]
                else:
                    xaug1[i] = kdash1[i]
            yaug1 = ydash1 * lbd + ydash * (1 - lbd)
            xaug.append(xaug1)
            yaug.append(yaug1)
    xs2 = np.asarray(xaug)
    ys2 = np.asarray(yaug)
    x1 = np.concatenate((xt, xs2))
    y1 = np.concatenate((yt, ys2))
    return x1, y1

# %%
xtt, ytt = stichup(xtrain_emb,y_train_o,3)
xtt.shape
# Out:
# (6600, 125)

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
import tensorflow as tf

Classifier_model = Sequential()
#add model layers
Classifier_model.Input = (125,)

Classifier_model.add(Dense(512,activation='relu'))
Classifier_model.add(Dense(512,activation='relu'))

Classifier_model.add(Dense(5, activation='softmax'))
opt = tf.keras.optimizers.Adam(learning_rate=0.001)
Classifier_model.compile(optimizer=opt,loss='categorical_crossentropy',metrics=['accuracy'])
Classifier_model.fit(xtt, ytt,epochs=25, validation_data=(xtest_emb, y_test_o))
# Out:
# Epoch 1/25
# 207/207 [==============================] - 3s 6ms/step - loss: 0.2792 - accuracy: 0.9364 - val_loss: 0.6447 - val_accuracy: 0.7836
# Epoch 2/25
# 207/207 [==============================] - 1s 4ms/step - loss: 0.2321 - accuracy: 0.9488 - val_loss: 0.7544 - val_accuracy: 0.7818
# Epoch 3/25
# 207/207 [==============================] - 1s 4ms/step - loss: 0.2219 - accuracy: 0.9535 - val_loss: 0.7214 - val_accuracy: 0.7873
# Epoch 4/25
# 207/207 [==============================] - 1s 4ms/step - loss: 0.2125 - accuracy: 0.9606 - val_loss: 0.7410 - val_accuracy: 0.7836
# Epoch 5/25
# 207/207 [==============================] - 1s 3ms/step - loss: 0.2078 - accuracy: 0.9583 - val_loss: 0.7484 - val_accuracy: 0.7927
# Epoch 6/25
# 207/207 [==============================] - 1s 3ms/step - loss: 0.2004 - accuracy: 0.9639 - val_loss: 0.7614 - val_accuracy: 0.7836
# Epoch 7/25
# 207/207 [==============================] - 1s 3ms/step - loss: 0.1958 - accuracy: 0.9652 - val_loss: 0.7275 - val_accuracy: 0.7982
# Epoch 8/25
# 207/207 [==============================] - 1s 3ms/step - loss: 0.1904 - accuracy: 0.9685 - val_loss: 0.7537 - val_accuracy: 0.7873
# Epoch 9/25
# 207/207 [==============================] - 1s 4ms/step - loss: 0.1837 - accuracy: 0.9682 - val_loss: 0.7986 - val_accuracy: 0.7873
# Epoch 10/25
# 207/207 [==============================] - 1s 4ms/step - loss: 0.1795 - accuracy: 0.9726 - val_loss: 0.8101 - val_accuracy: 0.7727
# Epoch 11/25
# 207/207 [==============================] - 1s 3ms/step - loss: 0.1717 - accuracy: 0.9748 - val_loss: 0.8306 - val_accuracy: 0.7818
# Epoch 12/25
# 207/207 [==============================] - 1s 3ms/step - loss: 0.1688 - accuracy: 0.9720 - val_loss: 0.8990 - val_accuracy: 0.7855
# Epoch 13/25
# 207/207 [==============================] - 1s 3ms/step - loss: 0.1650 - accuracy: 0.9780 - val_loss: 0.7784 - val_accuracy: 0.8018
# Epoch 14/25
# 207/207 [==============================] - 1s 4ms/step - loss: 0.1620 - accuracy: 0.9774 - val_loss: 0.8670 - val_accuracy: 0.7782
# Epoch 15/25
# 207/207 [==============================] - 1s 4ms/step - loss: 0.1577 - accuracy: 0.9788 - val_loss: 0.8609 - val_accuracy: 0.7764
# Epoch 16/25
# 207/207 [==============================] - 1s 5ms/step - loss: 0.1540 - accuracy: 0.9770 - val_loss: 0.8667 - val_accuracy: 0.7909
# Epoch 17/25
# 207/207 [==============================] - 1s 5ms/step - loss: 0.1546 - accuracy: 0.9797 - val_loss: 0.9191 - val_accuracy: 0.7927
# Epoch 18/25
# 207/207 [==============================] - 1s 5ms/step - loss: 0.1503 - accuracy: 0.9803 - val_loss: 0.9655 - val_accuracy: 0.7836
# Epoch 19/25
# 207/207 [==============================] - 1s 3ms/step - loss: 0.1487 - accuracy: 0.9805 - val_loss: 0.8844 - val_accuracy: 0.7800
# Epoch 20/25
# 207/207 [==============================] - 1s 3ms/step - loss: 0.1493 - accuracy: 0.9777 - val_loss: 0.8997 - val_accuracy: 0.7745
# Epoch 21/25
# 207/207 [==============================] - 1s 3ms/step - loss: 0.1461 - accuracy: 0.9830 - val_loss: 0.9076 - val_accuracy: 0.7800
# Epoch 22/25
# 207/207 [==============================] - 1s 4ms/step - loss: 0.1470 - accuracy: 0.9820 - val_loss: 0.9583 - val_accuracy: 0.7745
# Epoch 23/25
# 207/207 [==============================] - 1s 3ms/step - loss: 0.1437 - accuracy: 0.9797 - val_loss: 0.9507 - val_accuracy: 0.7727
# Epoch 24/25
# 207/207 [==============================] - 1s 3ms/step - loss: 0.1452 - accuracy: 0.9824 - val_loss: 0.9505 - val_accuracy: 0.7764
# Epoch 25/25
# 207/207 [==============================] - 1s 3ms/step - loss: 0.1420 - accuracy: 0.9820 - val_loss: 0.8682 - val_accuracy: 0.7782

# %%
Classifier_model.evaluate(xtest_emb, y_test_o)
# Out:
# 18/18 [==============================] - 0s 2ms/step - loss: 0.8682 - accuracy: 0.7782
# [0.8681854605674744, 0.778181791305542]

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

# Assuming Classifier_model.predict returns probabilities or predicted classes
y_pred = Classifier_model.predict(xtest_emb)

# If y_pred contains probabilities, you may want to convert them to classes
# For binary classification:
# y_pred_classes = (y_pred > 0.5).astype(int)
# For multi-class classification with softmax output:
y_pred_classes = np.argmax(y_pred, axis=1)
from sklearn.metrics import classification_report

# Assuming y_pred_classes are predicted classes

# Generate classification report
report = classification_report(y_test, y_pred_classes, digits=5)

# Print the report
print("Classification Report:")
print(report)
# Out:
# 18/18 [==============================] - 0s 2ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0    0.86139   0.79817   0.82857       109
#            1    0.93636   0.88034   0.90749       117
#            2    0.83810   0.85437   0.84615       103
#            3    0.66667   0.63717   0.65158       113
#            4    0.61905   0.72222   0.66667       108
#
#     accuracy                        0.77818       550
#    macro avg    0.78431   0.77845   0.78009       550
# weighted avg    0.78538   0.77818   0.78050       550
