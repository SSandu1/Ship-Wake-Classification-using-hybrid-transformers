# %%
import numpy as np
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
from keras.models import Model
from keras.layers import Dense, GlobalAveragePooling2D
from keras.applications import DenseNet121
from sklearn.model_selection import train_test_split

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
x = np.load('/content/drive/MyDrive/N/resized_images.npy')
y = np.load('/content/drive/MyDrive/N/labels.npy')

# Perform train-test split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=7)

# Create DenseNet base
input_shape = x_train.shape[1:]  # Assuming x_train is a numpy array of images
input_shape
# Out:
# (128, 128, 3)

# %%
print(x_train.shape)
print(x_test.shape)
# Out:
# (2200, 128, 128, 3)
# (550, 128, 128, 3)

# %%
pip install vit-keras
# Out:
# Collecting vit-keras
#   Downloading vit_keras-0.1.2-py3-none-any.whl (24 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from vit-keras) (1.11.4)
# Collecting validators (from vit-keras)
#   Downloading validators-0.24.0-py3-none-any.whl (27 kB)
# Requirement already satisfied: numpy<1.28.0,>=1.21.6 in /usr/local/lib/python3.10/dist-packages (from scipy->vit-keras) (1.25.2)
# Installing collected packages: validators, vit-keras
# Successfully installed validators-0.24.0 vit-keras-0.1.2

# %%
pip install tensorflow-addons
# Out:
# Collecting tensorflow-addons
#   Downloading tensorflow_addons-0.23.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (611 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.8/611.8 kB 4.1 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow-addons) (24.0)
# Collecting typeguard<3.0.0,>=2.7 (from tensorflow-addons)
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Installing collected packages: typeguard, tensorflow-addons
# Successfully installed tensorflow-addons-0.23.0 typeguard-2.13.3

# %%
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.models import Model
from vit_keras import vit

def create_ViT_base(input_shape):
    # Load ViT model without the top layer
    base_model = vit.build_model(image_size=input_shape[0], patch_size=16, num_layers=12, activation='linear',
                                 classes = 5, hidden_size =144, num_heads = 12, name = 'ViT_Dem', mlp_dim = 512, include_top=False)

    # Perform global average pooling
    x = base_model.output
    #x = GlobalAveragePooling2D()(x)

    # Add a dense layer with 125 sigmoid activated neurons
    x = Dense(125, activation='sigmoid')(x)

    model = Model(inputs=base_model.input, outputs=x)
    return model

def create_classification_model(base_model, num_classes):
    # Freeze the base model layers
    for layer in base_model.layers:
        layer.trainable = True

    # Add a dense layer with softmax activation for classification
    x = Dense(num_classes, activation='softmax')(base_model.output)

    # Create the classification model
    model = Model(inputs=base_model.input, outputs=x)

    return model

base_model = create_ViT_base(input_shape)

num_classes = 5  # Change this to the number of classes in your classification task
classification_model = create_classification_model(base_model, num_classes)

classification_model.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 128, 128, 3)]     0
#
#  embedding (Conv2D)          (None, 8, 8, 144)         110736
#
#  reshape (Reshape)           (None, 64, 144)           0
#
#  class_token (ClassToken)    (None, 65, 144)           144
#
#  Transformer/posembed_input  (None, 65, 144)           9360
#   (AddPositionEmbs)
#
#  Transformer/encoderblock_0  ((None, 65, 144),         232208
#   (TransformerBlock)          (None, 12, None, None)
#                              )
#
#  Transformer/encoderblock_1  ((None, 65, 144),         232208
#   (TransformerBlock)          (None, 12, None, None)
#                              )
#
#  Transformer/encoderblock_2  ((None, 65, 144),         232208
#   (TransformerBlock)          (None, 12, None, None)
#                              )
#
#  Transformer/encoderblock_3  ((None, 65, 144),         232208
#   (TransformerBlock)          (None, 12, None, None)
#                              )
#
#  Transformer/encoderblock_4  ((None, 65, 144),         232208
#   (TransformerBlock)          (None, 12, None, None)
#                              )
#
#  Transformer/encoderblock_5  ((None, 65, 144),         232208
#   (TransformerBlock)          (None, 12, None, None)
#                              )
#
#  Transformer/encoderblock_6  ((None, 65, 144),         232208
#   (TransformerBlock)          (None, 12, None, None)
#                              )
#
#  Transformer/encoderblock_7  ((None, 65, 144),         232208
#   (TransformerBlock)          (None, 12, None, None)
#                              )
#
#  Transformer/encoderblock_8  ((None, 65, 144),         232208
#   (TransformerBlock)          (None, 12, None, None)
#                              )
#
#  Transformer/encoderblock_9  ((None, 65, 144),         232208
#   (TransformerBlock)          (None, 12, None, None)
#                              )
#
#  Transformer/encoderblock_1  ((None, 65, 144),         232208
#  0 (TransformerBlock)         (None, 12, None, None)
#                              )
#
#  Transformer/encoderblock_1  ((None, 65, 144),         232208
#  1 (TransformerBlock)         (None, 12, None, None)
#                              )
#
#  Transformer/encoder_norm (  (None, 65, 144)           288
#  LayerNormalization)
#
#  ExtractToken (Lambda)       (None, 144)               0
#
#  dense (Dense)               (None, 125)               18125
#
#  dense_1 (Dense)             (None, 5)                 630
#
# =================================================================
# Total params: 2925779 (11.16 MB)
# Trainable params: 2925779 (11.16 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
classification_model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Define callbacks
checkpoint = ModelCheckpoint("/content/drive/MyDrive/N/vit.h5", monitor='val_loss', verbose=1, save_best_only=True, mode='min')
early_stopping = EarlyStopping(monitor='val_loss', patience=7, verbose=1, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=1e-6, verbose=1)

# Train the model
history = classification_model.fit(x_train, y_train, epochs=25, batch_size=32, validation_data=(x_test, y_test), callbacks=[checkpoint, early_stopping, reduce_lr])
# Out:
# Epoch 1/25
# 69/69 [==============================] - ETA: 0s - loss: 1.6494 - accuracy: 0.2027
# Epoch 1: val_loss improved from inf to 1.61283, saving model to /content/drive/MyDrive/N/vit.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 69/69 [==============================] - 74s 156ms/step - loss: 1.6494 - accuracy: 0.2027 - val_loss: 1.6128 - val_accuracy: 0.1982 - lr: 0.0010
# Epoch 2/25
# 69/69 [==============================] - ETA: 0s - loss: 1.6264 - accuracy: 0.1827
# Epoch 2: val_loss did not improve from 1.61283
# 69/69 [==============================] - 7s 95ms/step - loss: 1.6264 - accuracy: 0.1827 - val_loss: 1.6172 - val_accuracy: 0.1964 - lr: 0.0010
# Epoch 3/25
# 69/69 [==============================] - ETA: 0s - loss: 1.6172 - accuracy: 0.2064
# Epoch 3: val_loss did not improve from 1.61283
# 69/69 [==============================] - 7s 106ms/step - loss: 1.6172 - accuracy: 0.2064 - val_loss: 1.6183 - val_accuracy: 0.2055 - lr: 0.0010
# Epoch 4/25
# 69/69 [==============================] - ETA: 0s - loss: 1.6190 - accuracy: 0.2014
# Epoch 4: val_loss did not improve from 1.61283
# 69/69 [==============================] - 7s 105ms/step - loss: 1.6190 - accuracy: 0.2014 - val_loss: 1.6190 - val_accuracy: 0.2055 - lr: 0.0010
# Epoch 5/25
# 69/69 [==============================] - ETA: 0s - loss: 1.6286 - accuracy: 0.1864
# Epoch 5: val_loss improved from 1.61283 to 1.61178, saving model to /content/drive/MyDrive/N/vit.h5
# 69/69 [==============================] - 8s 124ms/step - loss: 1.6286 - accuracy: 0.1864 - val_loss: 1.6118 - val_accuracy: 0.1964 - lr: 0.0010
# Epoch 6/25
# 69/69 [==============================] - ETA: 0s - loss: 1.6168 - accuracy: 0.2086
# Epoch 6: val_loss improved from 1.61178 to 1.60864, saving model to /content/drive/MyDrive/N/vit.h5
# 69/69 [==============================] - 7s 101ms/step - loss: 1.6168 - accuracy: 0.2086 - val_loss: 1.6086 - val_accuracy: 0.2127 - lr: 0.0010
# Epoch 7/25
# 69/69 [==============================] - ETA: 0s - loss: 1.6218 - accuracy: 0.1959
# Epoch 7: val_loss did not improve from 1.60864
# 69/69 [==============================] - 7s 104ms/step - loss: 1.6218 - accuracy: 0.1959 - val_loss: 1.6132 - val_accuracy: 0.2127 - lr: 0.0010
# Epoch 8/25
# 69/69 [==============================] - ETA: 0s - loss: 1.6151 - accuracy: 0.1936
# Epoch 8: val_loss did not improve from 1.60864
# 69/69 [==============================] - 6s 91ms/step - loss: 1.6151 - accuracy: 0.1936 - val_loss: 1.6176 - val_accuracy: 0.1964 - lr: 0.0010
# Epoch 9/25
# 69/69 [==============================] - ETA: 0s - loss: 1.6149 - accuracy: 0.2032
# Epoch 9: val_loss did not improve from 1.60864
# 69/69 [==============================] - 8s 110ms/step - loss: 1.6149 - accuracy: 0.2032 - val_loss: 1.6205 - val_accuracy: 0.1873 - lr: 0.0010
# Epoch 10/25
# 69/69 [==============================] - ETA: 0s - loss: 1.6172 - accuracy: 0.2018
# Epoch 10: val_loss did not improve from 1.60864
# 69/69 [==============================] - 6s 94ms/step - loss: 1.6172 - accuracy: 0.2018 - val_loss: 1.6186 - val_accuracy: 0.1873 - lr: 0.0010
# Epoch 11/25
# 69/69 [==============================] - ETA: 0s - loss: 1.6173 - accuracy: 0.1936
# Epoch 11: val_loss did not improve from 1.60864
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 69/69 [==============================] - 7s 98ms/step - loss: 1.6173 - accuracy: 0.1936 - val_loss: 1.6139 - val_accuracy: 0.2127 - lr: 0.0010
# Epoch 12/25
# 69/69 [==============================] - ETA: 0s - loss: 1.6129 - accuracy: 0.1941
# Epoch 12: val_loss did not improve from 1.60864
# 69/69 [==============================] - 7s 97ms/step - loss: 1.6129 - accuracy: 0.1941 - val_loss: 1.6105 - val_accuracy: 0.1873 - lr: 2.0000e-04
# Epoch 13/25
# 69/69 [==============================] - ETA: 0s - loss: 1.6107 - accuracy: 0.1905
# Epoch 13: val_loss did not improve from 1.60864
# Restoring model weights from the end of the best epoch: 6.
# 69/69 [==============================] - 7s 98ms/step - loss: 1.6107 - accuracy: 0.1905 - val_loss: 1.6107 - val_accuracy: 0.1964 - lr: 2.0000e-04
# Epoch 13: early stopping

# %%
classification_model.load_weights("/content/drive/MyDrive/N/vit.h5")
classification_model.evaluate(x_test, y_test)
# Out:
# 18/18 [==============================] - 1s 43ms/step - loss: 1.6086 - accuracy: 0.2127
# [1.6086379289627075, 0.21272727847099304]

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

# Assuming classification_model.predict returns probabilities or predicted classes
y_pred = classification_model.predict(x_test)

# If y_pred contains probabilities, you may want to convert them to classes
# For binary classification:
# y_pred_classes = (y_pred > 0.5).astype(int)

# For multi-class classification with softmax output:
y_pred_classes = np.argmax(y_pred, axis=1)
from sklearn.metrics import classification_report

# Assuming y_pred_classes are predicted classes

# Generate classification report
report = classification_report(y_test, y_pred_classes, digits=5)

# Print the report
print("Classification Report:")
print(report)
# Out:
# 18/18 [==============================] - 4s 42ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0    0.00000   0.00000   0.00000       109
#            1    0.21273   1.00000   0.35082       117
#            2    0.00000   0.00000   0.00000       103
#            3    0.00000   0.00000   0.00000       113
#            4    0.00000   0.00000   0.00000       108
#
#     accuracy                        0.21273       550
#    macro avg    0.04255   0.20000   0.07016       550
# weighted avg    0.04525   0.21273   0.07463       550
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Visualize t-SNE embeddings
# Assuming x_train_embed and x_test_embed are the embeddings obtained from the penultimate layer
tsne = TSNE(n_components=2, random_state=42)
x_embed = base_model.predict(x_test)  # Assuming x_test is your test data
x_tsne = tsne.fit_transform(x_embed)

# Plot t-SNE embeddings
plt.figure(figsize=(10, 8))
plt.scatter(x_tsne[:, 0], x_tsne[:, 1], c=y_test, cmap='viridis')
plt.colorbar()
plt.title(' Test t-SNE Embeddings')
plt.xlabel('t-SNE Component 1')
plt.ylabel('t-SNE Component 2')
plt.show()
# Out:
# 18/18 [==============================] - 3s 41ms/step

# %%
# Visualize t-SNE embeddings
# Assuming x_train_embed and x_test_embed are the embeddings obtained from the penultimate layer
x_test_flat = x_test.reshape((550, 128*128*3))
tsne = TSNE(n_components=2, random_state=42)
#x_embed = base_model.predict(x_test)  # Assuming x_test is your test data
x_tsne = tsne.fit_transform(x_test_flat)

# Plot t-SNE embeddings
plt.figure(figsize=(10, 8))
plt.scatter(x_tsne[:, 0], x_tsne[:, 1], c=y_test, cmap='viridis')
plt.colorbar()
plt.title(' Test Images')
plt.xlabel('t-SNE Component 1')
plt.ylabel('t-SNE Component 2')
plt.show()

# %%
# Visualize t-SNE embeddings
# Assuming x_train_embed and x_train_embed are the embeddings obtained from the penultimate layer
x_train_flat = x_train.reshape((2200, 128*128*3))
tsne = TSNE(n_components=2, random_state=42)
#x_embed = base_model.predict(x_train)  # Assuming x_train is your train data
x_tsne = tsne.fit_transform(x_train_flat)

# Plot t-SNE embeddings
plt.figure(figsize=(10, 8))
plt.scatter(x_tsne[:, 0], x_tsne[:, 1], c=y_train, cmap='viridis')
plt.colorbar()
plt.title('Train Images')
plt.xlabel('t-SNE Component 1')
plt.ylabel('t-SNE Component 2')
plt.show()

# %%
# Visualize t-SNE embeddings
# Assuming x_train_embed and x_train_embed are the embeddings obtained from the penultimate layer
tsne = TSNE(n_components=2, random_state=42)
x_embed = base_model.predict(x_train)  # Assuming x_train is your train data
x_tsne = tsne.fit_transform(x_embed)

# Plot t-SNE embeddings
plt.figure(figsize=(10, 8))
plt.scatter(x_tsne[:, 0], x_tsne[:, 1], c=y_train, cmap='viridis')
plt.colorbar()
plt.title('Train t-SNE Embeddings')
plt.xlabel('t-SNE Component 1')
plt.ylabel('t-SNE Component 2')
plt.show()
# Out:
# 69/69 [==============================] - 4s 56ms/step

# %% [markdown]
# <h1>E-Mixup

# %%
xtest_emb = base_model.predict(x_test)
xtrain_emb = base_model.predict(x_train)
# Out:
# 18/18 [==============================] - 1s 60ms/step
# 69/69 [==============================] - 3s 36ms/step

# %%
import keras
y_test_o = keras.utils.to_categorical(y_test)
y_train_o = keras.utils.to_categorical(y_train)
print(y_train_o.shape)
print(y_test_o.shape)
# Out:
# (2200, 5)
# (550, 5)

# %%
def mixup(xt, yt, mf):
  alp = 0.2
  xaug = []
  yaug = []
  for k in range(0,xt.shape[0]):
    cnt = 0
    for cnt in range(0,mf-1):
      lbd = np.random.beta(alp,alp)
      yks = np.random.randint(xt.shape[0])
      kdash = xt[yks]
      ydash = yt[yks]
      kdash1 = xt[k]
      ydash1 = yt[k]
      xaug1 = kdash1*lbd + kdash*(1-lbd)
      yaug1 = ydash1*lbd + ydash*(1-lbd)
      xaug.append(xaug1)
      yaug.append(yaug1)
  xs2 = np.asarray(xaug)
  ys2 = np.asarray(yaug)
  x1 = np.concatenate((xt,xs2))
  y1 = np.concatenate((yt,ys2))
  return x1,y1

# %%
xtrain_emb.shape
# Out:
# (2200, 125)

# %%
xtt, ytt = mixup(xtrain_emb,y_train_o,3)
xtt.shape
# Out:
# (6600, 125)

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
import tensorflow as tf

Classifier_model = Sequential()
#add model layers
Classifier_model.Input = (125,)

Classifier_model.add(Dense(512,activation='relu'))
Classifier_model.add(Dense(512,activation='relu'))

Classifier_model.add(Dense(5, activation='softmax'))
opt = tf.keras.optimizers.Adam(learning_rate=0.001)
Classifier_model.compile(optimizer=opt,loss='categorical_crossentropy',metrics=['accuracy'])
Classifier_model.fit(xtt, ytt,epochs=25, validation_data=(xtest_emb, y_test_o))
# Out:
# Epoch 1/25
# 207/207 [==============================] - 2s 4ms/step - loss: 1.6192 - accuracy: 0.1965 - val_loss: 1.6104 - val_accuracy: 0.1873
# Epoch 2/25
# 207/207 [==============================] - 1s 4ms/step - loss: 1.6099 - accuracy: 0.2017 - val_loss: 1.6099 - val_accuracy: 0.1873
# Epoch 3/25
# 207/207 [==============================] - 1s 4ms/step - loss: 1.6095 - accuracy: 0.2036 - val_loss: 1.6102 - val_accuracy: 0.1873
# Epoch 4/25
# 207/207 [==============================] - 1s 4ms/step - loss: 1.6095 - accuracy: 0.2062 - val_loss: 1.6101 - val_accuracy: 0.1873
# Epoch 5/25
# 207/207 [==============================] - 1s 5ms/step - loss: 1.6094 - accuracy: 0.2055 - val_loss: 1.6101 - val_accuracy: 0.1964
# Epoch 6/25
# 207/207 [==============================] - 1s 5ms/step - loss: 1.6094 - accuracy: 0.2053 - val_loss: 1.6105 - val_accuracy: 0.1873
# Epoch 7/25
# 207/207 [==============================] - 1s 5ms/step - loss: 1.6094 - accuracy: 0.2041 - val_loss: 1.6102 - val_accuracy: 0.1873
# Epoch 8/25
# 207/207 [==============================] - 1s 4ms/step - loss: 1.6094 - accuracy: 0.2062 - val_loss: 1.6103 - val_accuracy: 0.1873
# Epoch 9/25
# 207/207 [==============================] - 1s 3ms/step - loss: 1.6094 - accuracy: 0.2062 - val_loss: 1.6101 - val_accuracy: 0.1873
# Epoch 10/25
# 207/207 [==============================] - 1s 4ms/step - loss: 1.6095 - accuracy: 0.2062 - val_loss: 1.6102 - val_accuracy: 0.1873
# Epoch 11/25
# 207/207 [==============================] - 1s 3ms/step - loss: 1.6094 - accuracy: 0.2062 - val_loss: 1.6099 - val_accuracy: 0.1873
# Epoch 12/25
# 207/207 [==============================] - 1s 3ms/step - loss: 1.6094 - accuracy: 0.2062 - val_loss: 1.6101 - val_accuracy: 0.1873
# Epoch 13/25
# 207/207 [==============================] - 1s 4ms/step - loss: 1.6094 - accuracy: 0.2062 - val_loss: 1.6103 - val_accuracy: 0.1873
# Epoch 14/25
# 207/207 [==============================] - 1s 4ms/step - loss: 1.6094 - accuracy: 0.2062 - val_loss: 1.6103 - val_accuracy: 0.1873
# Epoch 15/25
# 207/207 [==============================] - 1s 4ms/step - loss: 1.6094 - accuracy: 0.2062 - val_loss: 1.6103 - val_accuracy: 0.1873
# Epoch 16/25
# 207/207 [==============================] - 1s 4ms/step - loss: 1.6094 - accuracy: 0.2062 - val_loss: 1.6102 - val_accuracy: 0.1873
# Epoch 17/25
# 207/207 [==============================] - 1s 4ms/step - loss: 1.6094 - accuracy: 0.2024 - val_loss: 1.6102 - val_accuracy: 0.1873
# Epoch 18/25
# 207/207 [==============================] - 1s 4ms/step - loss: 1.6094 - accuracy: 0.2062 - val_loss: 1.6102 - val_accuracy: 0.1873
# Epoch 19/25
# 207/207 [==============================] - 1s 4ms/step - loss: 1.6094 - accuracy: 0.2020 - val_loss: 1.6103 - val_accuracy: 0.1873
# Epoch 20/25
# 207/207 [==============================] - 1s 5ms/step - loss: 1.6094 - accuracy: 0.2062 - val_loss: 1.6102 - val_accuracy: 0.1873
# Epoch 21/25
# 207/207 [==============================] - 1s 6ms/step - loss: 1.6094 - accuracy: 0.2035 - val_loss: 1.6104 - val_accuracy: 0.1873
# Epoch 22/25
# 207/207 [==============================] - 1s 6ms/step - loss: 1.6094 - accuracy: 0.2062 - val_loss: 1.6102 - val_accuracy: 0.1873
# Epoch 23/25
# 207/207 [==============================] - 1s 6ms/step - loss: 1.6094 - accuracy: 0.2062 - val_loss: 1.6101 - val_accuracy: 0.1873
# Epoch 24/25
# 207/207 [==============================] - 1s 5ms/step - loss: 1.6094 - accuracy: 0.2062 - val_loss: 1.6103 - val_accuracy: 0.1873
# Epoch 25/25
# 207/207 [==============================] - 1s 4ms/step - loss: 1.6094 - accuracy: 0.2062 - val_loss: 1.6102 - val_accuracy: 0.1873

# %%
Classifier_model.evaluate(xtest_emb, y_test_o)
# Out:
# 18/18 [==============================] - 0s 3ms/step - loss: 1.6102 - accuracy: 0.1873
# [1.6101961135864258, 0.18727272748947144]

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

# Assuming Classifier_model.predict returns probabilities or predicted classes
y_pred = Classifier_model.predict(xtest_emb)

# If y_pred contains probabilities, you may want to convert them to classes
# For binary classification:
# y_pred_classes = (y_pred > 0.5).astype(int)
# For multi-class classification with softmax output:
y_pred_classes = np.argmax(y_pred, axis=1)
from sklearn.metrics import classification_report

# Assuming y_pred_classes are predicted classes

# Generate classification report
report = classification_report(y_test, y_pred_classes, digits=5)

# Print the report
print("Classification Report:")
print(report)
# Out:
# 18/18 [==============================] - 0s 2ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0    0.00000   0.00000   0.00000       109
#            1    0.00000   0.00000   0.00000       117
#            2    0.18727   1.00000   0.31547       103
#            3    0.00000   0.00000   0.00000       113
#            4    0.00000   0.00000   0.00000       108
#
#     accuracy                        0.18727       550
#    macro avg    0.03745   0.20000   0.06309       550
# weighted avg    0.03507   0.18727   0.05908       550
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# E-Stitchup

# %%
import numpy as np

def stichup(xt, yt, mf):
    alp = 0.2
    xaug = []
    yaug = []
    for k in range(xt.shape[0]):
        for _ in range(mf-1):  # Renamed loop counter to avoid confusion with loop index
            lbd = np.random.beta(alp, alp)
            yks = np.random.randint(xt.shape[0])
            kdash = xt[yks]  # Accessing rows of xt directly
            ydash = yt[yks]  # Accessing corresponding y value
            kdash1 = xt[k]    # Accessing rows of xt directly
            ydash1 = yt[k]    # Accessing corresponding y value
            lbd_stch = int(xt.shape[1] * lbd)
            reff_stich = np.zeros(xt.shape[1])
            for i in range(lbd_stch):
                index_stich = np.random.randint(xt.shape[1])
                reff_stich[index_stich] = 1
            xaug1 = np.zeros(xt.shape[1])  # Initialize as numpy array
            for i in range(len(reff_stich)):
                if reff_stich[i] == 0:
                    xaug1[i] = kdash[i]
                else:
                    xaug1[i] = kdash1[i]
            yaug1 = ydash1 * lbd + ydash * (1 - lbd)
            xaug.append(xaug1)
            yaug.append(yaug1)
    xs2 = np.asarray(xaug)
    ys2 = np.asarray(yaug)
    x1 = np.concatenate((xt, xs2))
    y1 = np.concatenate((yt, ys2))
    return x1, y1

# %%
xtt, ytt = stichup(xtrain_emb,y_train_o,3)
xtt.shape
# Out:
# (6600, 125)

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
import tensorflow as tf

Classifier_model = Sequential()
#add model layers
Classifier_model.Input = (125,)

Classifier_model.add(Dense(512,activation='relu'))
Classifier_model.add(Dense(512,activation='relu'))

Classifier_model.add(Dense(5, activation='softmax'))
opt = tf.keras.optimizers.Adam(learning_rate=0.001)
Classifier_model.compile(optimizer=opt,loss='categorical_crossentropy',metrics=['accuracy'])
Classifier_model.fit(xtt, ytt,epochs=25, validation_data=(xtest_emb, y_test_o))
# Out:
# Epoch 1/25
# 207/207 [==============================] - 2s 4ms/step - loss: 1.6194 - accuracy: 0.1903 - val_loss: 1.6090 - val_accuracy: 0.2127
# Epoch 2/25
# 207/207 [==============================] - 1s 4ms/step - loss: 1.6099 - accuracy: 0.2027 - val_loss: 1.6095 - val_accuracy: 0.1982
# Epoch 3/25
# 207/207 [==============================] - 1s 4ms/step - loss: 1.6096 - accuracy: 0.2008 - val_loss: 1.6096 - val_accuracy: 0.1982
# Epoch 4/25
# 207/207 [==============================] - 1s 4ms/step - loss: 1.6096 - accuracy: 0.1995 - val_loss: 1.6097 - val_accuracy: 0.1982
# Epoch 5/25
# 207/207 [==============================] - 1s 4ms/step - loss: 1.6095 - accuracy: 0.2035 - val_loss: 1.6096 - val_accuracy: 0.1982
# Epoch 6/25
# 207/207 [==============================] - 1s 4ms/step - loss: 1.6095 - accuracy: 0.2035 - val_loss: 1.6096 - val_accuracy: 0.1982
# Epoch 7/25
# 207/207 [==============================] - 1s 4ms/step - loss: 1.6095 - accuracy: 0.2035 - val_loss: 1.6099 - val_accuracy: 0.1982
# Epoch 8/25
# 207/207 [==============================] - 1s 3ms/step - loss: 1.6096 - accuracy: 0.2035 - val_loss: 1.6097 - val_accuracy: 0.1982
# Epoch 9/25
# 207/207 [==============================] - 1s 5ms/step - loss: 1.6095 - accuracy: 0.2035 - val_loss: 1.6097 - val_accuracy: 0.1982
# Epoch 10/25
# 207/207 [==============================] - 1s 5ms/step - loss: 1.6095 - accuracy: 0.1983 - val_loss: 1.6097 - val_accuracy: 0.1982
# Epoch 11/25
# 207/207 [==============================] - 1s 5ms/step - loss: 1.6095 - accuracy: 0.2035 - val_loss: 1.6097 - val_accuracy: 0.1982
# Epoch 12/25
# 207/207 [==============================] - 1s 4ms/step - loss: 1.6095 - accuracy: 0.1982 - val_loss: 1.6098 - val_accuracy: 0.1982
# Epoch 13/25
# 207/207 [==============================] - 1s 4ms/step - loss: 1.6095 - accuracy: 0.2035 - val_loss: 1.6098 - val_accuracy: 0.1982
# Epoch 14/25
# 207/207 [==============================] - 1s 4ms/step - loss: 1.6095 - accuracy: 0.2035 - val_loss: 1.6097 - val_accuracy: 0.1982
# Epoch 15/25
# 207/207 [==============================] - 1s 4ms/step - loss: 1.6095 - accuracy: 0.2035 - val_loss: 1.6098 - val_accuracy: 0.1982
# Epoch 16/25
# 207/207 [==============================] - 1s 4ms/step - loss: 1.6095 - accuracy: 0.2035 - val_loss: 1.6098 - val_accuracy: 0.1982
# Epoch 17/25
# 207/207 [==============================] - 1s 4ms/step - loss: 1.6095 - accuracy: 0.2029 - val_loss: 1.6097 - val_accuracy: 0.1982
# Epoch 18/25
# 207/207 [==============================] - 1s 3ms/step - loss: 1.6095 - accuracy: 0.2035 - val_loss: 1.6098 - val_accuracy: 0.1982
# Epoch 19/25
# 207/207 [==============================] - 1s 4ms/step - loss: 1.6095 - accuracy: 0.2035 - val_loss: 1.6097 - val_accuracy: 0.1982
# Epoch 20/25
# 207/207 [==============================] - 1s 4ms/step - loss: 1.6095 - accuracy: 0.2035 - val_loss: 1.6098 - val_accuracy: 0.1982
# Epoch 21/25
# 207/207 [==============================] - 1s 4ms/step - loss: 1.6095 - accuracy: 0.2035 - val_loss: 1.6098 - val_accuracy: 0.1982
# Epoch 22/25
# 207/207 [==============================] - 1s 4ms/step - loss: 1.6095 - accuracy: 0.2035 - val_loss: 1.6098 - val_accuracy: 0.1982
# Epoch 23/25
# 207/207 [==============================] - 1s 4ms/step - loss: 1.6095 - accuracy: 0.2035 - val_loss: 1.6098 - val_accuracy: 0.1982
# Epoch 24/25
# 207/207 [==============================] - 1s 4ms/step - loss: 1.6095 - accuracy: 0.2035 - val_loss: 1.6097 - val_accuracy: 0.1982
# Epoch 25/25
# 207/207 [==============================] - 1s 4ms/step - loss: 1.6095 - accuracy: 0.2035 - val_loss: 1.6097 - val_accuracy: 0.1982

# %%
Classifier_model.evaluate(xtest_emb, y_test_o)
# Out:
# 18/18 [==============================] - 0s 3ms/step - loss: 1.6097 - accuracy: 0.1982
# [1.6096601486206055, 0.19818182289600372]

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

# Assuming Classifier_model.predict returns probabilities or predicted classes
y_pred = Classifier_model.predict(xtest_emb)

# If y_pred contains probabilities, you may want to convert them to classes
# For binary classification:
# y_pred_classes = (y_pred > 0.5).astype(int)
# For multi-class classification with softmax output:
y_pred_classes = np.argmax(y_pred, axis=1)
from sklearn.metrics import classification_report

# Assuming y_pred_classes are predicted classes

# Generate classification report
report = classification_report(y_test, y_pred_classes, digits=5)

# Print the report
print("Classification Report:")
print(report)
# Out:
# 18/18 [==============================] - 0s 2ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0    0.19818   1.00000   0.33080       109
#            1    0.00000   0.00000   0.00000       117
#            2    0.00000   0.00000   0.00000       103
#            3    0.00000   0.00000   0.00000       113
#            4    0.00000   0.00000   0.00000       108
#
#     accuracy                        0.19818       550
#    macro avg    0.03964   0.20000   0.06616       550
# weighted avg    0.03928   0.19818   0.06556       550
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
